# %% [markdown]
# # Integrate Amazon Lookout for Metrics with Amazon Augmented AI (A2I)
#
# Amazon Lookout for Metrics can help you identify anomalies within your data metrics that you gather on a periodic basis. In this notebook we show how to pass the anomalous results for human review and use the feedback for improving model accuracy.
#
# We are extending the example usecase for Amazon Lookout for Metrics that was discussed in an [earlier blog](https://aws.amazon.com/blogs/machine-learning/introducing-amazon-lookout-for-metrics-an-anomaly-detection-service-to-proactively-monitor-the-health-of-your-business/) and integrating it with Amazon A2I.
#
#
# ## Workflow
#
# 1. Create a Detector and configure its detection properties.
# 2. Create a Metric Set:
#     1. Provide the location of your source data and the IAM permissions needed to access it.
#     1. Define the Metrics that you want to investigate.
#     1. Attach the dataset to your Detector.
# 3. Activate the Detector.
# 4. Pass the detected outliers to a human work team for review.
# 6. Provide feedback on the outliers to improve predictor model's accuracy.

# %% [markdown]
# ---
# ### 1.0. Prerequisites
#
# 1. The code uses Python 3.7. Please use the Python 3 (Data Science) kernel for this notebook.
# 2. If you need thsi Notebook to create an IAM role for Lookout For Metrics, SageMaker will need permissions to create the IAM role. You can find teh IAM role used by SageMaker Studio in the [SageMaker Studio Control Panel](https://docs.aws.amazon.com/sagemaker/latest/dg/onboard-quick-start.html).
#
# Note: It is OK to encounter the following error in the output of next cell.
# <br/><span style="color:tomato">ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# awscli 1.19.47 requires botocore==1.20.47, but you have botocore 1.20.91 which is incompatible.
# awscli 1.19.47 requires s3transfer<0.4.0,>=0.3.0, but you have s3transfer 0.4.2 which is incompatible.
# aiobotocore 1.2.2 requires botocore<1.19.53,>=1.19.52, but you have botocore 1.20.91 which is incompatible.</span>

# %%
# First, let's get the latest installations of our dependencies
## IGNORE ANY ERRORS ##
# !pip install --upgrade pip
# !pip install botocore --upgrade
# !pip install boto3 --upgrade
# !pip install -U botocore
# Out:
# Requirement already satisfied: pip in /opt/conda/lib/python3.7/site-packages (21.1.2)
# WARNING: Running pip as root will break packages and permissions. You should install packages reliably by using venv: https://pip.pypa.io/warnings/venv
# Requirement already satisfied: botocore in /opt/conda/lib/python3.7/site-packages (1.20.91)
# Collecting botocore
#   Downloading botocore-1.20.99-py2.py3-none-any.whl (7.6 MB)
#      |████████████████████████████████| 7.6 MB 9.4 MB/s eta 0:00:01
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in /opt/conda/lib/python3.7/site-packages (from botocore) (2.8.1)
# Requirement already satisfied: urllib3<1.27,>=1.25.4 in /opt/conda/lib/python3.7/site-packages (from botocore) (1.25.8)
# Requirement already satisfied: jmespath<1.0.0,>=0.7.1 in /opt/conda/lib/python3.7/site-packages (from botocore) (0.10.0)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.7/site-packages (from python-dateutil<3.0.0,>=2.1->botocore) (1.14.0)
# Installing collected packages: botocore
#   Attempting uninstall: botocore
#     Found existing installation: botocore 1.20.91
#     Uninstalling botocore-1.20.91:
#       Successfully uninstalled botocore-1.20.91
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# awscli 1.19.47 requires botocore==1.20.47, but you have botocore 1.20.99 which is incompatible.
# awscli 1.19.47 requires s3transfer<0.4.0,>=0.3.0, but you have s3transfer 0.4.2 which is incompatible.
# aiobotocore 1.2.2 requires botocore<1.19.53,>=1.19.52, but you have botocore 1.20.99 which is incompatible.
# Successfully installed botocore-1.20.99
# WARNING: Running pip as root will break packages and permissions. You should install packages reliably by using venv: https://pip.pypa.io/warnings/venv
# Requirement already satisfied: boto3 in /opt/conda/lib/python3.7/site-packages (1.17.91)
# Collecting boto3
#   Downloading boto3-1.17.99-py2.py3-none-any.whl (131 kB)
#      |████████████████████████████████| 131 kB 7.9 MB/s eta 0:00:01
# Requirement already satisfied: s3transfer<0.5.0,>=0.4.0 in /opt/conda/lib/python3.7/site-packages (from boto3) (0.4.2)
# Requirement already satisfied: jmespath<1.0.0,>=0.7.1 in /opt/conda/lib/python3.7/site-packages (from boto3) (0.10.0)
# Requirement already satisfied: botocore<1.21.0,>=1.20.99 in /opt/conda/lib/python3.7/site-packages (from boto3) (1.20.99)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in /opt/conda/lib/python3.7/site-packages (from botocore<1.21.0,>=1.20.99->boto3) (2.8.1)
# Requirement already satisfied: urllib3<1.27,>=1.25.4 in /opt/conda/lib/python3.7/site-packages (from botocore<1.21.0,>=1.20.99->boto3) (1.25.8)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.7/site-packages (from python-dateutil<3.0.0,>=2.1->botocore<1.21.0,>=1.20.99->boto3) (1.14.0)
# Installing collected packages: boto3
#   Attempting uninstall: boto3
#     Found existing installation: boto3 1.17.91
#     Uninstalling boto3-1.17.91:
#       Successfully uninstalled boto3-1.17.91
# Successfully installed boto3-1.17.99
# WARNING: Running pip as root will break packages and permissions. You should install packages reliably by using venv: https://pip.pypa.io/warnings/venv
# Requirement already satisfied: botocore in /opt/conda/lib/python3.7/site-packages (1.20.99)
# Requirement already satisfied: jmespath<1.0.0,>=0.7.1 in /opt/conda/lib/python3.7/site-packages (from botocore) (0.10.0)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in /opt/conda/lib/python3.7/site-packages (from botocore) (2.8.1)
# Requirement already satisfied: urllib3<1.27,>=1.25.4 in /opt/conda/lib/python3.7/site-packages (from botocore) (1.25.8)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.7/site-packages (from python-dateutil<3.0.0,>=2.1->botocore) (1.14.0)
# WARNING: Running pip as root will break packages and permissions. You should install packages reliably by using venv: https://pip.pypa.io/warnings/venv

# %%
import time
import os
import zipfile
import shutil
import datetime
import pprint
import json
import uuid
import re
import texttable as tt

import boto3
import pandas as pd
import numpy as np
import sagemaker
import botocore

# %% [markdown]
# ---
# ### 1.1. Create S3 bucket
#
# Create an S3 bucket where we will upload data for Amazon Lookout for Metrics. The bucket is created only if it does not already exist.

# %%
region = boto3.Session().region_name

account_id = boto3.client('sts').get_caller_identity().get('Account')

bucket_name = account_id + "-" + region + "-lookoutmetrics-lab"


# Use SageMaker's default S3 bucket, where training output will be stored. 
#bucket_name = session.default_bucket()  # Custom bucket name can be used.
#print ("S3 Bucket Name: " + bucket_name)

#Create the bucket of it does not exist
s3 = boto3.resource('s3')
exists = True
if s3.Bucket(bucket_name).creation_date is None:
    exists = False

if not exists:
    try:
        if  region == 'us-east-1':
          s3.create_bucket(Bucket=bucket_name)
        else: 
          s3.create_bucket(Bucket=bucket_name, CreateBucketConfiguration={ 'LocationConstraint': region })
        print('S3 bucket {} created successfully'.format(bucket_name))
    except Exception as e:
        print('S3 error: ', e)
else: 
    print("S3 Bucket: {} already exists.".format(bucket_name))
# Out:
# S3 Bucket: 095351214964-us-west-2-lookoutmetrics-lab already exists.

# %% [markdown]
# ---
# ### 1.2. Configure IAM Role
#
# Create an IAM role that will be assumed by Amazon Lookout for Metrics service and will allow it to communicate with S3.

# %%
iam = boto3.client("iam")

role_name = "L4M_iam_role"

assume_role_policy_document = {
    "Version": "2012-10-17",
    "Statement": [
        {
            "Effect": "Allow",
            "Principal": {
                "Service": "lookoutmetrics.amazonaws.com"
            },
            "Action": "sts:AssumeRole"
        }
    ]
}

try:
    create_role_response = iam.create_role(
        RoleName = role_name,
        AssumeRolePolicyDocument = json.dumps(assume_role_policy_document)
    )
    role_arn = create_role_response["Role"]["Arn"]
    
    print("Created %s" % role_name)
    print("Attaching policies")

    iam.attach_role_policy(
        RoleName=role_name,
        PolicyArn='arn:aws:iam::aws:policy/AmazonS3FullAccess',
    )
    print("Waiting for a minute to allow IAM role policy attachment to propagate")
    time.sleep(60)


except iam.exceptions.EntityAlreadyExistsException:
    print("Role %s already existed" % role_name )
    role_arn = boto3.resource('iam').Role(role_name).arn


#iam.attach_role_policy(
#    RoleName = role_name,
#    PolicyArn = "arn:aws:iam::aws:policy/AmazonSNSFullAccess"
#)

print(role_arn)
# Out:
# Role L4M_iam_role already existed
# arn:aws:iam::095351214964:role/L4M_iam_role

# %% [markdown]
# ---
# ### 2.0. Generate synthetic data
#
# We will generate data both for training the detector and for prediction of anomalies. In this example the detector will be used in continuous mode to detect anomalies. Starting from the current date, we generate data for a default period of 6 months in the past and 3 days in the future. The period is configurable through constants defined in the next cell.
#
# The historical data is used for training the model, while the future data will be used for predicting anomalies on an ongoing basis.
#
# * Historical data will be created as a csv file called "./data/ecommerce/backtest/input.csv"
# * Hourly data files will be stored in folder, "./data/ecommerce/live/{yyyyMMdd}/{HH:mm}/{yyyyMMdd_HH:mm:ss}.csv"
# * Complete data along with the anomaly labels is available in "./data/ecommerce/label.csv"
#
# The data in local folders is replaced based on current date, on every execution of this section.
#
# *Note: Synthetic data generation may take about 4 minutes.*

# %%
# local folders for data
DATASET_NAME = "ecommerce"
DIR_PATH = './data'

#######################################################################
# Set constants for the duration of historical and future periods for data generation.
NUM_MONTHS_HISTORICAL_DATA = 6
NUM_DAYS_FUTURE_DATA = 3

# Metrics will be received at the top of every hour.
FREQUENCY = "PT1H" # one of 'P1D', 'PT1H', 'PT10M' and 'PT5M'
#######################################################################

# %% [markdown]
# ---
# ### 2.1. Generate data

# %%
# %%time

import os
import math
import random
import itertools
import datetime
from datetime import date
from dateutil.relativedelta import relativedelta
import shutil
import pandas as pd

dimensions = { "platform" : [ "pc_web", "mobile_web", "mobile_app" ], "marketplace" : [ "us", "uk", "de", "fr", "es", "it", "jp" ] }
metrics = [ "views", "revenue" ]

metric_period = "1H"

daily_peak_size_range = ( 200, 400 )
daily_peak_time = ( 12 * 60, 21 * 60 )
daily_offset_range = ( 100, 200 )

random_factor_size_range = (2, 10)

anomaly_size_range = ( 100, 600 )
anomaly_length_range = ( 1, 5 * 60 )
anomaly_possibility = 0.005
#anomaly_possibility = 0.2

introduce_metric_from_upstream = [
    lambda x : max( int(x), 0 ),    # sin curve -> views 
    lambda x : x * 0.3,             # views -> revenue
]

random.seed(1234)

class DailyPattern:
    
    def __init__( self ):
        self.peak_size = random.uniform( *daily_peak_size_range )
        self.peak_time = random.uniform( *daily_peak_time )
        self.offset = random.uniform( *daily_offset_range )
    
    def get( self, t ):
        
        minutes_in_day = t.hour * 60 + t.minute
        
        factor1 = math.cos( (( minutes_in_day - self.peak_time ) / ( 24 * 60 )) * 2 * math.pi ) * self.peak_size + self.peak_size + self.offset
        
        return factor1

class RandomFactor:
    
    def __init__( self ):
        self.size = random.uniform( *random_factor_size_range )

    def get(self):
        return random.uniform( -self.size, self.size )


class Anomaly:
    
    def __init__(self):
        self.remaining_time = random.randint( *anomaly_length_range )
        self.offset = random.uniform( *anomaly_size_range ) * (random.randint(0,1)*2-1)
        #print( self.offset )

    def proceed_time(self):
        self.remaining_time -= pd.to_timedelta(metric_period).seconds / 60
        return self.remaining_time <= 0

    def get(self):
        return self.offset

class Item:

    def __init__( self, dimension ):
        
        #print( dimension )
        
        self.dimension = dimension
        
        self.daily_pattern = DailyPattern()
        self.random_factor = RandomFactor()
        self.anomaly = None
    
    def get( self, t ):
    
        if random.random() < anomaly_possibility:
            self.anomaly = Anomaly()
        
        value = self.daily_pattern.get(t)
        
        value += self.random_factor.get()

        is_anomaly = bool(self.anomaly)
        if self.anomaly:
            value += self.anomaly.get()
            if self.anomaly.proceed_time():
                self.anomaly = None
        
        metric_values = []
        for i, metric in enumerate(metrics):
            value = introduce_metric_from_upstream[i](value)
            metric_values.append(value)
        
        #if (is_anomaly):
            #print (metric_values, is_anomaly)
        
        return metric_values, is_anomaly


def synthesize(period):

    # create item list
    item_list = []
    for dimension_values in itertools.product( *dimensions.values() ):
        item = Item( dict( zip( dimensions.keys(), dimension_values ) ) )
        item_list.append(item)
    
    # itereate and prepare data    
    dimension_values_list = []
    for i in range( len(dimensions) ):
        dimension_values_list.append([])

    timestamp_list = []

    metric_values_list = []
    for i, metric in enumerate(metrics):
        metric_values_list.append([])

    labels_list = []
    for i, metric in enumerate(metrics):
        labels_list.append([])
    
    t = period[0]
    while t<period[1]:
        
        #print(t)

        for item in item_list:
            
            for i, d in enumerate(item.dimension.values()):
                #print(i,d)
                dimension_values_list[i].append(d)
            
            timestamp_list.append(t)
            
            metric_values, is_anomaly = item.get(t)
            for i, metric_value in enumerate(metric_values):
                metric_values_list[i].append(metric_value)
                labels_list[i].append( int(is_anomaly) )

        t += pd.to_timedelta(metric_period)
        
    # convert to DataFrame
    data = {}
    for dimension_name, dimension_values in zip( dimensions.keys(), dimension_values_list ):
        data[dimension_name] = dimension_values
    data["timestamp"] = timestamp_list
    for metric_name, metric_values in zip( metrics, metric_values_list ):
        data[metric_name] = metric_values
    for metric_name, labels in zip( metrics, labels_list ):
        data[metric_name + "_label"] = labels    
    df = pd.DataFrame(data)
    return df


def splot_into_intervals( df, output_dirname ):

    #print(df.head())
    df["views"] *= random.uniform(0.1, 2.0)
    df["views"] = df["views"].apply(lambda x: int(x))

    df["revenue"] *= random.uniform(0.1, 2.0)
    df["revenue"] = df["revenue"].apply(lambda x: round(x, 2))
    #print(df.head())
    
    for timestamp, df_single_timestamp in df.groupby("timestamp"):        
        dirname = os.path.join( output_dirname, timestamp.strftime( "%Y%m%d/%H%M" ) )
        filename = os.path.join( dirname, timestamp.strftime("%Y%m%d_%H%M%S.csv") )

        if not os.path.exists(dirname):
            os.makedirs( dirname )
        
        df_single_timestamp.to_csv( filename, index=False, date_format="%Y-%m-%d %H:%M:%S" )


def generate_data(period, data_type):
    
    df_full = synthesize(period)
    
    # Create new ones:
    if not os.path.exists("./data/{}/{}".format(DATASET_NAME,data_type)):
        os.makedirs("./data/{}/{}".format(DATASET_NAME,data_type))

    df_full.to_csv( "./data/%s/label.csv" % DATASET_NAME, index=False )
    label_colunn_names = [ metric_name + "_label" for metric_name in metrics ]
    df_input = df_full.drop( columns = label_colunn_names )
    
    if (data_type == "backtest"):
        df_input.to_csv( "./data/{}/backtest/input.csv".format(DATASET_NAME), index=False )
    else:
        splot_into_intervals( df_input, "./data/{}/live".format(DATASET_NAME))


# Get rid of old files:
try:
    shutil.rmtree(DIR_PATH, ignore_errors=False, onerror=None)
except:
    print('Error while deleting directory')

start = date.today() + relativedelta(months =- NUM_MONTHS_HISTORICAL_DATA)
end = date.today()
period = (datetime.datetime(start.year, start.month, start.day), datetime.datetime(end.year, end.month, end.day))

generate_data(period, "backtest")

start = date.today()
end = date.today()  + relativedelta(days =+ NUM_DAYS_FUTURE_DATA)
period = (datetime.datetime(start.year, start.month, start.day), datetime.datetime(end.year, end.month, end.day))

generate_data(period, "live")
# Out:
# CPU times: user 2.2 s, sys: 87.9 ms, total: 2.29 s
# Wall time: 5.99 s

# %%
backtest_df = pd.read_csv('data/ecommerce/backtest/input.csv')
backtest_df.head()
# Out:
#   platform marketplace            timestamp  views  revenue
# 0   pc_web          us  2020-12-10 00:00:00    298     89.4
# 1   pc_web          uk  2020-12-10 00:00:00    476    142.8
# 2   pc_web          de  2020-12-10 00:00:00    152     45.6
# 3   pc_web          fr  2020-12-10 00:00:00    405    121.5
# 4   pc_web          es  2020-12-10 00:00:00    113     33.9

# %% [markdown]
# ---
# ### 2.2. Save data to S3 bucket
#
# Save the data into the s3 bucket created earlier.
#
# *Will take about 1 min 30 sec.*

# %%
# %%time
# !aws s3 sync {DIR_PATH}/{DATASET_NAME}/ s3://{bucket_name}/{DATASET_NAME}/ --quiet --delete
# Out:
# CPU times: user 26.9 ms, sys: 8.61 ms, total: 35.5 ms
# Wall time: 1.84 s

# %% [markdown]
# ### 3.0. Create Lookout for Metrics Detector
#
# The `Detector` is a machine learning model that detects outliers in the metrics. The detector is automatically trained with the machine learning algorithm that best fits your data and use case. You can optionally provide your historical data for training, if you have any. Otherwise, get started with real-time data, and Amazon Lookout for Metrics will learn on-the-go. For this example we provide 6 months of historical data.
#
# You specify the Amazon S3 location that Amazon Lookout for Metrics should continuously monitor for new data, and your detector analyzes your data and returns information about the outliers that it detected. When you create a `Detector`, you also specify a `detecting domain` and an `outlier detection frequency`.
#
# The `anomaly detection frequency` specifies how frequently the detector should wake-up and look for new data, run analysis and alert you with any interesting findings. For this example, the detector will look for anomalies at the top of every hour.

# %%
L4M = boto3.client( "lookoutmetrics")

ecom_anomaly_detector_name = "ecommerce-continuous-detector"
ecom_anomaly_detector_arn = ''

detector_list =[]

# Check if the eCommerce detector already exists 
list_anomaly_detectors_response = L4M.list_anomaly_detectors(MaxResults=100)

anomaly_detectors_list = list_anomaly_detectors_response['AnomalyDetectorSummaryList']

#print("Anomaly detectors list:\n {}".format(anomaly_detectors_list))

for anomaly_detector in anomaly_detectors_list:
    
    #print('anomaly_detector: {}'.format(anomaly_detector))

    if anomaly_detector['AnomalyDetectorName'] == ecom_anomaly_detector_name:
        # the detector for ecommerce example exists. Get its ARN
        ecom_anomaly_detector_arn = anomaly_detector['AnomalyDetectorArn']
        break

if len(ecom_anomaly_detector_arn) == 0:
    # Detector for ecommerce example does not exists. Create the anomaly detector.
    create_anomaly_detector_response = L4M.create_anomaly_detector( 
        AnomalyDetectorName = ecom_anomaly_detector_name,
        AnomalyDetectorDescription = "Anomaly detection on a sample ecommerce dataset.",
        AnomalyDetectorConfig = {
            "AnomalyDetectorFrequency" : FREQUENCY,   
        },
    )

    ecom_anomaly_detector_arn = create_anomaly_detector_response["AnomalyDetectorArn"]
    
print('\nAnomaly Detector ARN:\n{}'.format(ecom_anomaly_detector_arn))
# Out:
# Anomaly Detector ARN:
# arn:aws:lookoutmetrics:us-west-2:095351214964:AnomalyDetector:ecommerce-continuous-detector

# %% [markdown]
# ---
# ### 3.1. Define Metrics
#
# ### Measures and Dimensions
#
# `Measures` are variables or key performance indicators on which customers want to detect outliers and `Dimensions` are meta-data that represent categorical information about the measures.
#
# In this E-commerce example, views and revenue are our measures, and platform and marketplace are our dimensions. Customers may want to monitor their data for anomalies in number of views or revenue for every platform, marketplace, and combination of both. You can designate up to five measures and five dimensions per dataset.
#
# ### Metrics
#
# After creating a detector, and mapping your measures and dimensions, Amazon Lookout for Metrics will analyze each combination of these measures and dimensions. For the above example, we have of 7 unique values (us, jp, de, etc.) for marketplace and 3 unique values (mobile web, mobile app, pc web) for platform for a total of 21 unique combinations. Each unique combination of measures with the dimension values (e.g. us/mobile app/revenue) is a time series `metric`. In this case, we have 21 dimensions and 2 measures for a total of 42 time-series `metrics`.
#
# Amazon Lookout for Metrics detects anomalies at the most granular level so you are able to pin-point any unexpected behavior in your data.
#
# ### Datasets
#
# Measures, dimensions and metrics map to `datasets`, which also contain the Amazon S3 locations of your source data, an IAM role that has both read and write permissions to those Amazon S3 locations, and the rate at which data should be ingested from the source location (the upload frequency and data ingestion delay).

# %%
# Check if the metric set for this example exists

ecom_metric_set_name = "ecommerce-metric-set"
ecom_metric_set_arn = ''

metric_sets_list =[]


list_metric_sets_response = L4M.list_metric_sets(
        AnomalyDetectorArn=ecom_anomaly_detector_arn,
        MaxResults=100)

metric_sets_list = list_metric_sets_response['MetricSetSummaryList']
#print("Anomaly detectors list:\n {}".format(metric_sets_list))

for metric_set in metric_sets_list:
    
    #print('metric_set: {}'.format(metric_set))

    if metric_set['MetricSetName'] == ecom_metric_set_name:
        
        ecom_metric_set_arn = metric_set['MetricSetArn']
        print("\nMetric Set ARN:\n{}".format(ecom_metric_set_arn))
        
        break
# Out:
# Metric Set ARN:
# arn:aws:lookoutmetrics:us-west-2:095351214964:MetricSet/ecommerce-continuous-detector/ecommerce-metric-set

# %%
# If metric set for this example is not found, create it.
if len(ecom_metric_set_arn) == 0:
    s3_path_format = 's3://'+ bucket_name + '/ecommerce/live/{{yyyyMMdd}}/{{HHmm}}'
    s3_historical_path_prefix = 's3://'+ bucket_name + '/ecommerce/backtest/input.csv'


    params = {
        "AnomalyDetectorArn": ecom_anomaly_detector_arn,
        "MetricSetName" : ecom_metric_set_name,
        "MetricList" : [
            {
                "MetricName" : "views",
                "AggregationFunction" : "SUM",
            },
            {
                "MetricName" : "revenue",
                "AggregationFunction" : "SUM",
            },
        ],

        "DimensionList" : [ "platform", "marketplace" ],

        "TimestampColumn" : {
            "ColumnName" : "timestamp",
            "ColumnFormat" : "yyyy-MM-dd HH:mm:ss",
        },

        #"Delay" : 120, # seconds the detector will wait before attempting to read latest data per current time and detection frequency below
        "MetricSetFrequency" : FREQUENCY,

        "MetricSource" : {
            "S3SourceConfig": {
                "RoleArn" : role_arn,
                "HistoricalDataPathList": [
                    s3_historical_path_prefix,
                ],
                "TemplatedPathList": [
                    s3_path_format,
                ],

                "FileFormatDescriptor" : {
                    "CsvFormatDescriptor" : {
                        "FileCompression" : "NONE",
                        "Charset" : "UTF-8",
                        "ContainsHeader" : True,
                        "Delimiter" : ",",
                        "QuoteSymbol" : '"'
                    },
                }
            }
        },
    }

    create_metric_set_response = L4M.create_metric_set( ** params )
    ecom_metric_set_arn = create_metric_set_response["MetricSetArn"]

print("\nMetric Set ARN: {}".format(ecom_metric_set_arn))
# Out:
# Metric Set ARN: arn:aws:lookoutmetrics:us-west-2:095351214964:MetricSet/ecommerce-continuous-detector/ecommerce-metric-set

# %% [markdown]
# ---
# ### 4.0. Activate the Detector
#
# During activation the model is trained with historical data that was generated above and stored in the "./data/ecommerce/backtest" folder.
#
# *The activation process can take about 20 minutes.*

# %%
# %%time

# get detector details
describe_anomaly_detector_response =L4M.describe_anomaly_detector(
    AnomalyDetectorArn=ecom_anomaly_detector_arn)

#print("\nEcommerce Detector details: ")
#pprint.pprint(describe_anomaly_detector_response, width = 2)

ecom_detector_status = describe_anomaly_detector_response['Status']

if ecom_detector_status in ["INACTIVE", "ACTIVATING"]:
    
    # Activate the detector
    if ecom_detector_status == "INACTIVE":
        L4M.activate_anomaly_detector(AnomalyDetectorArn = ecom_anomaly_detector_arn)
    
        print("\nActivating ecommerce example Detector.")
    
    # Check status every 10 secs untile detector is ACTIVE
    while (ecom_detector_status in ["ACTIVATING", "INACTIVE", "LEARNING"]):
        response = L4M.describe_anomaly_detector( AnomalyDetectorArn = ecom_anomaly_detector_arn )
        ecom_detector_status = response["Status"]
        if ecom_detector_status == "ACTIVE" :
            break;
        else: 
            time.sleep(10)
            print("Detector status: {}".format(ecom_detector_status))
    
elif ecom_detector_status == "ACTIVE":
    print("\nEcommerce example detector is Active")
else:
    print("\nEcommerce Detector Status: {}".format(ecom_detector_status))
    print("\nDelete old detector in console and rerun this notebook.")
# Out:
# Activating ecommerce example Detector.
# Detector status: ACTIVATING
# Detector status: ACTIVATING
# Detector status: ACTIVATING
# Detector status: ACTIVATING
# Detector status: ACTIVATING
# Detector status: ACTIVATING
# Detector status: ACTIVATING
# Detector status: ACTIVATING
# Detector status: ACTIVATING
# Detector status: ACTIVATING
# Detector status: ACTIVATING
# Detector status: ACTIVATING
# Detector status: ACTIVATING
# Detector status: ACTIVATING
# Detector status: ACTIVATING
# Detector status: ACTIVATING
# Detector status: ACTIVATING
# Detector status: ACTIVATING
# Detector status: ACTIVATING
# Detector status: ACTIVATING
# Detector status: ACTIVATING
# Detector status: ACTIVATING
# Detector status: ACTIVATING
# Detector status: ACTIVATING
# Detector status: ACTIVATING
# Detector status: ACTIVATING
# Detector status: ACTIVATING
# Detector status: ACTIVATING
# Detector status: ACTIVATING
# Detector status: ACTIVATING
# Detector status: ACTIVATING
# Detector status: ACTIVATING
# Detector status: ACTIVATING
# Detector status: ACTIVATING
# Detector status: ACTIVATING
# Detector status: ACTIVATING
# Detector status: ACTIVATING
# Detector status: ACTIVATING
# Detector status: ACTIVATING
# Detector status: ACTIVATING
# Detector status: ACTIVATING
# Detector status: ACTIVATING
# Detector status: ACTIVATING
# Detector status: ACTIVATING
# Detector status: ACTIVATING
# Detector status: ACTIVATING
# Detector status: ACTIVATING
# Detector status: ACTIVATING
# Detector status: ACTIVATING
# Detector status: ACTIVATING
# Detector status: ACTIVATING
# Detector status: ACTIVATING
# Detector status: ACTIVATING
# Detector status: ACTIVATING
# Detector status: ACTIVATING
# Detector status: ACTIVATING
# Detector status: ACTIVATING
# Detector status: ACTIVATING
# Detector status: ACTIVATING
# Detector status: ACTIVATING
# Detector status: ACTIVATING
# Detector status: ACTIVATING
# Detector status: ACTIVATING
# Detector status: ACTIVATING
# Detector status: ACTIVATING
# Detector status: ACTIVATING
# Detector status: ACTIVATING
# Detector status: ACTIVATING
# Detector status: ACTIVATING
# Detector status: ACTIVATING
# Detector status: ACTIVATING
# Detector status: ACTIVATING
# Detector status: ACTIVATING
# Detector status: ACTIVATING
# Detector status: ACTIVATING
# Detector status: ACTIVATING
# Detector status: ACTIVATING
# Detector status: ACTIVATING
# Detector status: ACTIVATING
# Detector status: ACTIVATING
# Detector status: ACTIVATING
# Detector status: ACTIVATING
# Detector status: ACTIVATING
# Detector status: ACTIVATING
# Detector status: ACTIVATING
# Detector status: ACTIVATING
# Detector status: ACTIVATING
# Detector status: ACTIVATING
# Detector status: ACTIVATING
# Detector status: ACTIVATING
# Detector status: ACTIVATING
# Detector status: ACTIVATING
# Detector status: ACTIVATING
# Detector status: ACTIVATING
# Detector status: ACTIVATING
# Detector status: ACTIVATING
# Detector status: ACTIVATING
# Detector status: ACTIVATING
# Detector status: ACTIVATING
# Detector status: ACTIVATING
# Detector status: ACTIVATING
# Detector status: ACTIVATING
# Detector status: ACTIVATING
# Detector status: ACTIVATING
# Detector status: ACTIVATING
# Detector status: ACTIVATING
# Detector status: ACTIVATING
# Detector status: ACTIVATING
# Detector status: ACTIVATING
# Detector status: ACTIVATING
# Detector status: ACTIVATING
# Detector status: ACTIVATING
# Detector status: LEARNING
# Detector status: LEARNING
# Detector status: LEARNING
# Detector status: LEARNING
# Detector status: LEARNING
# Detector status: LEARNING
# Detector status: LEARNING
# Detector status: LEARNING
# Detector status: LEARNING
# Detector status: LEARNING
# Detector status: LEARNING
# Detector status: LEARNING
# Detector status: LEARNING
# Detector status: LEARNING
# Detector status: LEARNING
# Detector status: LEARNING
# Detector status: LEARNING
# Detector status: LEARNING
# Detector status: LEARNING
# Detector status: LEARNING
# Detector status: LEARNING
# Detector status: LEARNING
# Detector status: LEARNING
# Detector status: LEARNING
# Detector status: LEARNING
# Detector status: LEARNING
# Detector status: LEARNING
# Detector status: LEARNING
# Detector status: LEARNING
# Detector status: LEARNING
# Detector status: LEARNING
# Detector status: LEARNING
# Detector status: LEARNING
# Detector status: LEARNING
# Detector status: LEARNING
# Detector status: LEARNING
# Detector status: LEARNING
# Detector status: LEARNING
# Detector status: LEARNING
# Detector status: LEARNING
# Detector status: LEARNING
# Detector status: LEARNING
# Detector status: LEARNING
# Detector status: LEARNING
# Detector status: LEARNING
# Detector status: LEARNING
# Detector status: LEARNING
# Detector status: LEARNING
# Detector status: LEARNING
# Detector status: LEARNING
# Detector status: LEARNING
# Detector status: LEARNING
# Detector status: LEARNING
# Detector status: LEARNING
# Detector status: LEARNING
# Detector status: LEARNING
# Detector status: LEARNING
# Detector status: LEARNING
# Detector status: LEARNING
# Detector status: LEARNING
# Detector status: LEARNING
# Detector status: LEARNING
# Detector status: LEARNING
# Detector status: LEARNING
# Detector status: LEARNING
# Detector status: LEARNING
# Detector status: LEARNING
# Detector status: LEARNING
# Detector status: LEARNING
# Detector status: LEARNING
# Detector status: LEARNING
# Detector status: LEARNING
# Detector status: LEARNING
# Detector status: LEARNING
# Detector status: LEARNING
# Detector status: LEARNING
# Detector status: LEARNING
# Detector status: LEARNING
# Detector status: LEARNING
# Detector status: LEARNING
# Detector status: LEARNING
# CPU times: user 806 ms, sys: 123 ms, total: 929 ms
# Wall time: 32min 21s

# %% [markdown]
# ---
# ### 5.0. Fetch Anomalies
#
# We have created a continuous detector that will operate on live data. It expects to receive input data every hour. We already generated some data into the future and you can find it in the "./data/ecommerce/live" folder.
#
# **Note:**
# *You may have to wait for the detector to run at the top of the hour to detect anomalies. So, if no anomalies are found when executing the next cell, you may want to come back later and run it again.*

# %%
#ecom_anomaly_detector_arn = 'arn:aws:lookoutmetrics:us-west-2:095351214964:AnomalyDetector:my-detector'
#ecom_anomaly_detector_name = "my-detector"

############################
anomaly_score_cutoff = 50
############################

anomaly_groups = []
next_token = None

while True:    
    params = {
        "AnomalyDetectorArn" : ecom_anomaly_detector_arn,
        "SensitivityThreshold" : anomaly_score_cutoff,
        "MaxResults" : 100,
    }

    if next_token:
        params["NextToken"] = next_token

    response = L4M.list_anomaly_group_summaries(**params )
    
    print("Anomaly group summaries:\n {}".format(response))

    anomaly_groups += response["AnomalyGroupSummaryList"]
    print('\ntype of AnomalyGroupSummaryList: {}'.format(type(anomaly_groups)))
    
    for entry in anomaly_groups:
        print('\nAnomaly group id: {}, Anomaly group score: {}'.format(entry['AnomalyGroupId'], entry['AnomalyGroupScore']))
        
    if "NextToken" in response:
        next_token = response["NextToken"]
        continue

    break

if len(anomaly_groups) == 0:
    print("\nAnomalies not found")
# Out:
# Anomaly group summaries:
#  {'ResponseMetadata': {'RequestId': '12880a79-3f41-4a3b-b1a7-a36babb41e21', 'HTTPStatusCode': 200, 'HTTPHeaders': {'date': 'Thu, 24 Jun 2021 03:10:16 GMT', 'content-type': 'application/x-amz-json-1.1', 'content-length': '1560', 'connection': 'keep-alive', 'x-amzn-requestid': '12880a79-3f41-4a3b-b1a7-a36babb41e21', 'x-amz-apigw-id': 'BaOf1G4PvHcFWtw=', 'x-amzn-trace-id': 'Root=1-60d3f798-6089d5e1165f35676916c331'}, 'RetryAttempts': 0}, 'AnomalyGroupSummaryList': [{'StartTime': '2021-06-11T09:00Z[UTC]', 'EndTime': '2021-06-11T23:00Z[UTC]', 'AnomalyGroupId': '5bbce1b9-a075-46cd-b060-f6c3dfe732c5', 'AnomalyGroupScore': 86.78, 'PrimaryMetricName': 'views'}, {'StartTime': '2021-06-11T12:00Z[UTC]', 'EndTime': '2021-06-11T13:00Z[UTC]', 'AnomalyGroupId': 'c6c9ef45-8c59-4676-91ee-8193f45f7357', 'AnomalyGroupScore': 86.78, 'PrimaryMetricName': 'revenue'}, {'StartTime': '2021-06-11T11:00Z[UTC]', 'EndTime': '2021-06-11T11:00Z[UTC]', 'AnomalyGroupId': '093a06b5-60ca-4d93-a687-93e2838047d3', 'AnomalyGroupScore': 86.78, 'PrimaryMetricName': 'revenue'}, {'StartTime': '2021-06-11T10:00Z[UTC]', 'EndTime': '2021-06-11T10:00Z[UTC]', 'AnomalyGroupId': '51fa1473-3d49-4c52-bafc-217d779a762b', 'AnomalyGroupScore': 86.78, 'PrimaryMetricName': 'revenue'}, {'StartTime': '2021-06-10T17:00Z[UTC]', 'EndTime': '2021-06-11T02:00Z[UTC]', 'AnomalyGroupId': '8bcf8de1-6f82-4272-a822-5b1cc2a5b1a0', 'AnomalyGroupScore': 100.0, 'PrimaryMetricName': 'views'}, {'StartTime': '2021-06-10T21:00Z[UTC]', 'EndTime': '2021-06-10T21:00Z[UTC]', 'AnomalyGroupId': '2c1e158f-7da7-47c2-a50f-40807935411b', 'AnomalyGroupScore': 86.78, 'PrimaryMetricName': 'revenue'}, {'StartTime': '2021-06-10T18:00Z[UTC]', 'EndTime': '2021-06-10T18:00Z[UTC]', 'AnomalyGroupId': '47f65ef2-db1e-4ee9-8f3a-0ed4bc002b6b', 'AnomalyGroupScore': 79.42, 'PrimaryMetricName': 'revenue'}, {'StartTime': '2021-06-10T17:00Z[UTC]', 'EndTime': '2021-06-10T17:00Z[UTC]', 'AnomalyGroupId': '3febf42f-77a7-4bfe-afb1-24f256563495', 'AnomalyGroupScore': 97.92, 'PrimaryMetricName': 'revenue'}]}
#
# type of AnomalyGroupSummaryList: <class 'list'>
#
# Anomaly group id: 5bbce1b9-a075-46cd-b060-f6c3dfe732c5, Anomaly group score: 86.78
#
# Anomaly group id: c6c9ef45-8c59-4676-91ee-8193f45f7357, Anomaly group score: 86.78
#
# Anomaly group id: 093a06b5-60ca-4d93-a687-93e2838047d3, Anomaly group score: 86.78
#
# Anomaly group id: 51fa1473-3d49-4c52-bafc-217d779a762b, Anomaly group score: 86.78
#
# Anomaly group id: 8bcf8de1-6f82-4272-a822-5b1cc2a5b1a0, Anomaly group score: 100.0
#
# Anomaly group id: 2c1e158f-7da7-47c2-a50f-40807935411b, Anomaly group score: 86.78
#
# Anomaly group id: 47f65ef2-db1e-4ee9-8f3a-0ed4bc002b6b, Anomaly group score: 79.42
#
# Anomaly group id: 3febf42f-77a7-4bfe-afb1-24f256563495, Anomaly group score: 97.92

# %% [markdown]
# ---
# ### 5.1. Build a Pandas Dataframe with anomaly details to pass to human workflow
#
# Iterate over the anomaly results and build a dataframe. For each measure in an anomaly group, we fetch the list of anomalous metrics. For each anomalous dimension and its value, we get an associated system generated time series id. After human review of anomalies, we will need the time series id for each metric to when we register human feedback into Lookout Metrics to improve future prediction results.
# We save the time series id along with the timestamp and metric details into a new dataframe.

# %%
def datetime_from_string(s):
    try:
        dt = datetime.datetime.fromisoformat(s.split("[")[0])
    except ValueError:
        dt = datetime.datetime.strptime(s.split("[")[0], "%Y-%m-%dT%H:%MZ")
    
    return dt

def get_input_file_name(dt):
    time_tuple = t.timetuple()
    print("t: {}".format(time_tuple))
    year = str(time_tuple.tm_year).zfill(4)
    mon = str(time_tuple.tm_mon).zfill(2)
    day = str(time_tuple.tm_mday).zfill(2)
    hour = str(time_tuple.tm_hour).zfill(2)
    minute = str(time_tuple.tm_min).zfill(2)
    sec = str(time_tuple.tm_sec).zfill(2)
    file_name = '{6}/{7}/live/{0}{1}{2}/{3}{4}/{0}{1}{2}_{3}{4}{5}.csv'.format(year, mon, day, hour, minute, sec, DIR_PATH, DATASET_NAME)
        
    return file_name
    
    
# Since our metrics period is 1 hour
frequency_timedelta = datetime.timedelta(hours=1)

df_anomalies_list = []
dimension_names_set = set()

time_series_list = []
df_anomaly_file = pd.DataFrame()

for anomaly_group in anomaly_groups:

    print("\n\n")
    pprint.pprint(anomaly_group, width = 2)
    
    start_time = datetime_from_string( anomaly_group["StartTime"] )
    end_time = datetime_from_string( anomaly_group["EndTime"] )
    
    anomaly_group_id = anomaly_group["AnomalyGroupId"]
    anomaly_group_score = anomaly_group["AnomalyGroupScore"]
    primary_metric_name = anomaly_group["PrimaryMetricName"]
    
    next_token = None

    while True:    

        params = {
            "AnomalyDetectorArn" : ecom_anomaly_detector_arn,
            "AnomalyGroupId" : anomaly_group_id,
            "MetricName" : primary_metric_name,
            "MaxResults" : 100,
        }

        if next_token:
            params["NextToken"] = next_token

        anomaly_group_time_series_response = L4M.list_anomaly_group_time_series( **params )

        time_series_list += anomaly_group_time_series_response["TimeSeriesList"]
        
        if "NextToken" in response:
            next_token = response["NextToken"]
            continue

        break
    
    #print("\nAnomaly group time series: ")
    #pprint.pprint(anomaly_group_time_series_response, width = 2)

    #print("\nTime Series list: {}".format(time_series_list))

    for time_series in time_series_list:
        # time_series will have a lists of dimensions, metric values along with associted time series id
        data = {}
        dimension_dict = {}
        dim_names_set = set()
        
        data['tseriesid'] = time_series['TimeSeriesId']
        
        for dim_in_tseries in time_series["DimensionList"]:
            #dim_names_set.add(dim_in_tseries["DimensionName"])
            dimension_dict[dim_in_tseries["DimensionName"]] = dim_in_tseries["DimensionValue"]
            #dimension_dict['metric_name'] = primary_metric_name          
            
            #data[dimension["DimensionName"]] = [ dimension["DimensionValue"]]
            dimension_names_set.add(dim_in_tseries["DimensionName"])
            #data[primary_metric_name + "_group_score"] = [anomaly_group_score]
        
        print("data: {}".format(data))
        
        t = start_time
        
        while t <= end_time:
            
            file_name = get_input_file_name(t)
            print("File name: {}".format(file_name))
            
            df_from_csv = pd.read_csv(file_name) 
            #print("df_from_csv: {}".format(df_from_csv))
            
            df_temp = df_from_csv
            # drop rows where the dimension does not match
            for dim_name in dimension_dict:
                dim_value = dimension_dict[dim_name]
                print("dim_name: " + dim_name + ", dim value: " + dim_value)
                df_temp = df_temp[df_temp[dim_name] == dim_value] #drop rows
                
            df_temp['tseriesid'] = time_series['TimeSeriesId']
            df_temp['anomaly_group_id'] = anomaly_group_id
            df_temp['anomaly_metric'] = primary_metric_name
            df_temp['anomaly_metric_value'] = df_temp[primary_metric_name]
            
            #print("df_temp: {}".format(df_temp.to_string()))
            
            df_anomalies_list.append(df_temp)
            t += frequency_timedelta


if len(df_anomalies_list) > 0:
    df_anomalies_by_ts = pd.concat(df_anomalies_list)

    # fold multiple metrics into same rows
    df_anomalies_by_ts = df_anomalies_by_ts.groupby(["timestamp", *dimension_names_set], as_index=False).max() 
    print("Anomalies saved in dataframe.")
else:
    print("No anomalies found.")


print("\ndf_anomalies_by_ts:\n" + str(df_anomalies_by_ts))
# Out:
# {'AnomalyGroupId': '5bbce1b9-a075-46cd-b060-f6c3dfe732c5',
#  'AnomalyGroupScore': 86.78,
#  'EndTime': '2021-06-11T23:00Z[UTC]',
#  'PrimaryMetricName': 'views',
#  'StartTime': '2021-06-11T09:00Z[UTC]'}
# data: {'tseriesid': '806ed8e77d183d791ea7e239568f7466fa0150f5c5e195f661db6fb2fb6d875ce9f21a3ff024830c6d4a6e5a0eea32211b772d217e5d708d59be320fcb1f6793'}
# t: time.struct_time(tm_year=2021, tm_mon=6, tm_mday=11, tm_hour=9, tm_min=0, tm_sec=0, tm_wday=4, tm_yday=162, tm_isdst=-1)
# File name: ./data/ecommerce/live/20210611/0900/20210611_090000.csv
# dim_name: marketplace, dim value: jp
# dim_name: platform, dim value: mobile_web
# t: time.struct_time(tm_year=2021, tm_mon=6, tm_mday=11, tm_hour=10, tm_min=0, tm_sec=0, tm_wday=4, tm_yday=162, tm_isdst=-1)
# File name: ./data/ecommerce/live/20210611/1000/20210611_100000.csv
# dim_name: marketplace, dim value: jp
# dim_name: platform, dim value: mobile_web
# t: time.struct_time(tm_year=2021, tm_mon=6, tm_mday=11, tm_hour=11, tm_min=0, tm_sec=0, tm_wday=4, tm_yday=162, tm_isdst=-1)
# File name: ./data/ecommerce/live/20210611/1100/20210611_110000.csv
# dim_name: marketplace, dim value: jp
# dim_name: platform, dim value: mobile_web
# t: time.struct_time(tm_year=2021, tm_mon=6, tm_mday=11, tm_hour=12, tm_min=0, tm_sec=0, tm_wday=4, tm_yday=162, tm_isdst=-1)
# File name: ./data/ecommerce/live/20210611/1200/20210611_120000.csv
# dim_name: marketplace, dim value: jp
# dim_name: platform, dim value: mobile_web
# t: time.struct_time(tm_year=2021, tm_mon=6, tm_mday=11, tm_hour=13, tm_min=0, tm_sec=0, tm_wday=4, tm_yday=162, tm_isdst=-1)
# File name: ./data/ecommerce/live/20210611/1300/20210611_130000.csv
# dim_name: marketplace, dim value: jp
# dim_name: platform, dim value: mobile_web
# t: time.struct_time(tm_year=2021, tm_mon=6, tm_mday=11, tm_hour=14, tm_min=0, tm_sec=0, tm_wday=4, tm_yday=162, tm_isdst=-1)
# File name: ./data/ecommerce/live/20210611/1400/20210611_140000.csv
# dim_name: marketplace, dim value: jp
# dim_name: platform, dim value: mobile_web
# t: time.struct_time(tm_year=2021, tm_mon=6, tm_mday=11, tm_hour=15, tm_min=0, tm_sec=0, tm_wday=4, tm_yday=162, tm_isdst=-1)
# File name: ./data/ecommerce/live/20210611/1500/20210611_150000.csv
# dim_name: marketplace, dim value: jp
# dim_name: platform, dim value: mobile_web
# t: time.struct_time(tm_year=2021, tm_mon=6, tm_mday=11, tm_hour=16, tm_min=0, tm_sec=0, tm_wday=4, tm_yday=162, tm_isdst=-1)
# File name: ./data/ecommerce/live/20210611/1600/20210611_160000.csv
# dim_name: marketplace, dim value: jp
# dim_name: platform, dim value: mobile_web
# t: time.struct_time(tm_year=2021, tm_mon=6, tm_mday=11, tm_hour=17, tm_min=0, tm_sec=0, tm_wday=4, tm_yday=162, tm_isdst=-1)
# File name: ./data/ecommerce/live/20210611/1700/20210611_170000.csv
# dim_name: marketplace, dim value: jp
# dim_name: platform, dim value: mobile_web
# t: time.struct_time(tm_year=2021, tm_mon=6, tm_mday=11, tm_hour=18, tm_min=0, tm_sec=0, tm_wday=4, tm_yday=162, tm_isdst=-1)
# File name: ./data/ecommerce/live/20210611/1800/20210611_180000.csv
# dim_name: marketplace, dim value: jp
# dim_name: platform, dim value: mobile_web
# t: time.struct_time(tm_year=2021, tm_mon=6, tm_mday=11, tm_hour=19, tm_min=0, tm_sec=0, tm_wday=4, tm_yday=162, tm_isdst=-1)
# File name: ./data/ecommerce/live/20210611/1900/20210611_190000.csv
# dim_name: marketplace, dim value: jp
# dim_name: platform, dim value: mobile_web
# t: time.struct_time(tm_year=2021, tm_mon=6, tm_mday=11, tm_hour=20, tm_min=0, tm_sec=0, tm_wday=4, tm_yday=162, tm_isdst=-1)
# File name: ./data/ecommerce/live/20210611/2000/20210611_200000.csv
# dim_name: marketplace, dim value: jp
# dim_name: platform, dim value: mobile_web
# t: time.struct_time(tm_year=2021, tm_mon=6, tm_mday=11, tm_hour=21, tm_min=0, tm_sec=0, tm_wday=4, tm_yday=162, tm_isdst=-1)
# File name: ./data/ecommerce/live/20210611/2100/20210611_210000.csv
# dim_name: marketplace, dim value: jp
# dim_name: platform, dim value: mobile_web
# t: time.struct_time(tm_year=2021, tm_mon=6, tm_mday=11, tm_hour=22, tm_min=0, tm_sec=0, tm_wday=4, tm_yday=162, tm_isdst=-1)
# File name: ./data/ecommerce/live/20210611/2200/20210611_220000.csv
# dim_name: marketplace, dim value: jp
# dim_name: platform, dim value: mobile_web
# t: time.struct_time(tm_year=2021, tm_mon=6, tm_mday=11, tm_hour=23, tm_min=0, tm_sec=0, tm_wday=4, tm_yday=162, tm_isdst=-1)
# File name: ./data/ecommerce/live/20210611/2300/20210611_230000.csv
# dim_name: marketplace, dim value: jp
# dim_name: platform, dim value: mobile_web
# data: {'tseriesid': 'ae6a56fa750ccb9aaf2e19e03c9bf443677eddab1146cdac2004109b2beb9a1fcccb2902871a9f3a9c87d1b166f710509f2feccfd4b36dbbb292a0345e353bd2'}
# t: time.struct_time(tm_year=2021, tm_mon=6, tm_mday=11, tm_hour=9, tm_min=0, tm_sec=0, tm_wday=4, tm_yday=162, tm_isdst=-1)
# File name: ./data/ecommerce/live/20210611/0900/20210611_090000.csv
# dim_name: marketplace, dim value: de
# dim_name: platform, dim value: pc_web
# t: time.struct_time(tm_year=2021, tm_mon=6, tm_mday=11, tm_hour=10, tm_min=0, tm_sec=0, tm_wday=4, tm_yday=162, tm_isdst=-1)
# File name: ./data/ecommerce/live/20210611/1000/20210611_100000.csv
# dim_name: marketplace, dim value: de
# dim_name: platform, dim value: pc_web
# t: time.struct_time(tm_year=2021, tm_mon=6, tm_mday=11, tm_hour=11, tm_min=0, tm_sec=0, tm_wday=4, tm_yday=162, tm_isdst=-1)
# File name: ./data/ecommerce/live/20210611/1100/20210611_110000.csv
# dim_name: marketplace, dim value: de
# dim_name: platform, dim value: pc_web
# t: time.struct_time(tm_year=2021, tm_mon=6, tm_mday=11, tm_hour=12, tm_min=0, tm_sec=0, tm_wday=4, tm_yday=162, tm_isdst=-1)
# File name: ./data/ecommerce/live/20210611/1200/20210611_120000.csv
# dim_name: marketplace, dim value: de
# dim_name: platform, dim value: pc_web
# t: time.struct_time(tm_year=2021, tm_mon=6, tm_mday=11, tm_hour=13, tm_min=0, tm_sec=0, tm_wday=4, tm_yday=162, tm_isdst=-1)
# File name: ./data/ecommerce/live/20210611/1300/20210611_130000.csv
# dim_name: marketplace, dim value: de
# dim_name: platform, dim value: pc_web
# t: time.struct_time(tm_year=2021, tm_mon=6, tm_mday=11, tm_hour=14, tm_min=0, tm_sec=0, tm_wday=4, tm_yday=162, tm_isdst=-1)
# File name: ./data/ecommerce/live/20210611/1400/20210611_140000.csv
# dim_name: marketplace, dim value: de
# dim_name: platform, dim value: pc_web
# t: time.struct_time(tm_year=2021, tm_mon=6, tm_mday=11, tm_hour=15, tm_min=0, tm_sec=0, tm_wday=4, tm_yday=162, tm_isdst=-1)
# File name: ./data/ecommerce/live/20210611/1500/20210611_150000.csv
# dim_name: marketplace, dim value: de
# dim_name: platform, dim value: pc_web
# t: time.struct_time(tm_year=2021, tm_mon=6, tm_mday=11, tm_hour=16, tm_min=0, tm_sec=0, tm_wday=4, tm_yday=162, tm_isdst=-1)
# File name: ./data/ecommerce/live/20210611/1600/20210611_160000.csv
# dim_name: marketplace, dim value: de
# dim_name: platform, dim value: pc_web
# t: time.struct_time(tm_year=2021, tm_mon=6, tm_mday=11, tm_hour=17, tm_min=0, tm_sec=0, tm_wday=4, tm_yday=162, tm_isdst=-1)
# File name: ./data/ecommerce/live/20210611/1700/20210611_170000.csv
# dim_name: marketplace, dim value: de
# dim_name: platform, dim value: pc_web
# t: time.struct_time(tm_year=2021, tm_mon=6, tm_mday=11, tm_hour=18, tm_min=0, tm_sec=0, tm_wday=4, tm_yday=162, tm_isdst=-1)
# File name: ./data/ecommerce/live/20210611/1800/20210611_180000.csv
# dim_name: marketplace, dim value: de
# dim_name: platform, dim value: pc_web
# t: time.struct_time(tm_year=2021, tm_mon=6, tm_mday=11, tm_hour=19, tm_min=0, tm_sec=0, tm_wday=4, tm_yday=162, tm_isdst=-1)
# File name: ./data/ecommerce/live/20210611/1900/20210611_190000.csv
# dim_name: marketplace, dim value: de
# dim_name: platform, dim value: pc_web
# t: time.struct_time(tm_year=2021, tm_mon=6, tm_mday=11, tm_hour=20, tm_min=0, tm_sec=0, tm_wday=4, tm_yday=162, tm_isdst=-1)
# File name: ./data/ecommerce/live/20210611/2000/20210611_200000.csv
# dim_name: marketplace, dim value: de
# dim_name: platform, dim value: pc_web
# t: time.struct_time(tm_year=2021, tm_mon=6, tm_mday=11, tm_hour=21, tm_min=0, tm_sec=0, tm_wday=4, tm_yday=162, tm_isdst=-1)
# File name: ./data/ecommerce/live/20210611/2100/20210611_210000.csv
# dim_name: marketplace, dim value: de
# dim_name: platform, dim value: pc_web
# t: time.struct_time(tm_year=2021, tm_mon=6, tm_mday=11, tm_hour=22, tm_min=0, tm_sec=0, tm_wday=4, tm_yday=162, tm_isdst=-1)
# File name: ./data/ecommerce/live/20210611/2200/20210611_220000.csv
# dim_name: marketplace, dim value: de
# dim_name: platform, dim value: pc_web
# t: time.struct_time(tm_year=2021, tm_mon=6, tm_mday=11, tm_hour=23, tm_min=0, tm_sec=0, tm_wday=4, tm_yday=162, tm_isdst=-1)
# File name: ./data/ecommerce/live/20210611/2300/20210611_230000.csv
# dim_name: marketplace, dim value: de
# dim_name: platform, dim value: pc_web
# data: {'tseriesid': 'f2762c3d8bfd7a091b6c00fd13b8f75ee4a488038c84f161b9024062ef721a7c1f6c0196309a6783c59f76f6ca2f155614b0873f94a9dae01af684a8c164c1b2'}
# t: time.struct_time(tm_year=2021, tm_mon=6, tm_mday=11, tm_hour=9, tm_min=0, tm_sec=0, tm_wday=4, tm_yday=162, tm_isdst=-1)
# File name: ./data/ecommerce/live/20210611/0900/20210611_090000.csv
# dim_name: marketplace, dim value: es
# dim_name: platform, dim value: mobile_web
# t: time.struct_time(tm_year=2021, tm_mon=6, tm_mday=11, tm_hour=10, tm_min=0, tm_sec=0, tm_wday=4, tm_yday=162, tm_isdst=-1)
# File name: ./data/ecommerce/live/20210611/1000/20210611_100000.csv
# dim_name: marketplace, dim value: es
# dim_name: platform, dim value: mobile_web
# t: time.struct_time(tm_year=2021, tm_mon=6, tm_mday=11, tm_hour=11, tm_min=0, tm_sec=0, tm_wday=4, tm_yday=162, tm_isdst=-1)
# File name: ./data/ecommerce/live/20210611/1100/20210611_110000.csv
# dim_name: marketplace, dim value: es
# dim_name: platform, dim value: mobile_web
# t: time.struct_time(tm_year=2021, tm_mon=6, tm_mday=11, tm_hour=12, tm_min=0, tm_sec=0, tm_wday=4, tm_yday=162, tm_isdst=-1)
# File name: ./data/ecommerce/live/20210611/1200/20210611_120000.csv
# dim_name: marketplace, dim value: es
# dim_name: platform, dim value: mobile_web
# t: time.struct_time(tm_year=2021, tm_mon=6, tm_mday=11, tm_hour=13, tm_min=0, tm_sec=0, tm_wday=4, tm_yday=162, tm_isdst=-1)
# File name: ./data/ecommerce/live/20210611/1300/20210611_130000.csv
# dim_name: marketplace, dim value: es
# dim_name: platform, dim value: mobile_web
# t: time.struct_time(tm_year=2021, tm_mon=6, tm_mday=11, tm_hour=14, tm_min=0, tm_sec=0, tm_wday=4, tm_yday=162, tm_isdst=-1)
# File name: ./data/ecommerce/live/20210611/1400/20210611_140000.csv
# dim_name: marketplace, dim value: es
# dim_name: platform, dim value: mobile_web
# t: time.struct_time(tm_year=2021, tm_mon=6, tm_mday=11, tm_hour=15, tm_min=0, tm_sec=0, tm_wday=4, tm_yday=162, tm_isdst=-1)
# File name: ./data/ecommerce/live/20210611/1500/20210611_150000.csv
# dim_name: marketplace, dim value: es
# dim_name: platform, dim value: mobile_web
# t: time.struct_time(tm_year=2021, tm_mon=6, tm_mday=11, tm_hour=16, tm_min=0, tm_sec=0, tm_wday=4, tm_yday=162, tm_isdst=-1)
# File name: ./data/ecommerce/live/20210611/1600/20210611_160000.csv
# dim_name: marketplace, dim value: es
# dim_name: platform, dim value: mobile_web
# t: time.struct_time(tm_year=2021, tm_mon=6, tm_mday=11, tm_hour=17, tm_min=0, tm_sec=0, tm_wday=4, tm_yday=162, tm_isdst=-1)
# File name: ./data/ecommerce/live/20210611/1700/20210611_170000.csv
# dim_name: marketplace, dim value: es
# dim_name: platform, dim value: mobile_web
# t: time.struct_time(tm_year=2021, tm_mon=6, tm_mday=11, tm_hour=18, tm_min=0, tm_sec=0, tm_wday=4, tm_yday=162, tm_isdst=-1)
# File name: ./data/ecommerce/live/20210611/1800/20210611_180000.csv
# dim_name: marketplace, dim value: es
# dim_name: platform, dim value: mobile_web
# t: time.struct_time(tm_year=2021, tm_mon=6, tm_mday=11, tm_hour=19, tm_min=0, tm_sec=0, tm_wday=4, tm_yday=162, tm_isdst=-1)
# File name: ./data/ecommerce/live/20210611/1900/20210611_190000.csv
# dim_name: marketplace, dim value: es
# dim_name: platform, dim value: mobile_web
# t: time.struct_time(tm_year=2021, tm_mon=6, tm_mday=11, tm_hour=20, tm_min=0, tm_sec=0, tm_wday=4, tm_yday=162, tm_isdst=-1)
# File name: ./data/ecommerce/live/20210611/2000/20210611_200000.csv
# dim_name: marketplace, dim value: es
# dim_name: platform, dim value: mobile_web
# t: time.struct_time(tm_year=2021, tm_mon=6, tm_mday=11, tm_hour=21, tm_min=0, tm_sec=0, tm_wday=4, tm_yday=162, tm_isdst=-1)
# File name: ./data/ecommerce/live/20210611/2100/20210611_210000.csv
# dim_name: marketplace, dim value: es
# dim_name: platform, dim value: mobile_web
# t: time.struct_time(tm_year=2021, tm_mon=6, tm_mday=11, tm_hour=22, tm_min=0, tm_sec=0, tm_wday=4, tm_yday=162, tm_isdst=-1)
# File name: ./data/ecommerce/live/20210611/2200/20210611_220000.csv
# dim_name: marketplace, dim value: es
# dim_name: platform, dim value: mobile_web
# t: time.struct_time(tm_year=2021, tm_mon=6, tm_mday=11, tm_hour=23, tm_min=0, tm_sec=0, tm_wday=4, tm_yday=162, tm_isdst=-1)
# File name: ./data/ecommerce/live/20210611/2300/20210611_230000.csv
# dim_name: marketplace, dim value: es
# dim_name: platform, dim value: mobile_web
# data: {'tseriesid': '01982cf679fe2eb34d34b2bb81b9cc70ca5705f5357da7a47172cb5bc71f7cdc0c656ab6cb4d2e38bc96106490ae2d2351756b069b289eabab00f53cb0c2367f'}
# t: time.struct_time(tm_year=2021, tm_mon=6, tm_mday=11, tm_hour=9, tm_min=0, tm_sec=0, tm_wday=4, tm_yday=162, tm_isdst=-1)
# File name: ./data/ecommerce/live/20210611/0900/20210611_090000.csv
# dim_name: marketplace, dim value: de
# dim_name: platform, dim value: mobile_web
# t: time.struct_time(tm_year=2021, tm_mon=6, tm_mday=11, tm_hour=10, tm_min=0, tm_sec=0, tm_wday=4, tm_yday=162, tm_isdst=-1)
# File name: ./data/ecommerce/live/20210611/1000/20210611_100000.csv
# dim_name: marketplace, dim value: de
# dim_name: platform, dim value: mobile_web
# t: time.struct_time(tm_year=2021, tm_mon=6, tm_mday=11, tm_hour=11, tm_min=0, tm_sec=0, tm_wday=4, tm_yday=162, tm_isdst=-1)
# File name: ./data/ecommerce/live/20210611/1100/20210611_110000.csv
# dim_name: marketplace, dim value: de
# dim_name: platform, dim value: mobile_web
# t: time.struct_time(tm_year=2021, tm_mon=6, tm_mday=11, tm_hour=12, tm_min=0, tm_sec=0, tm_wday=4, tm_yday=162, tm_isdst=-1)
# File name: ./data/ecommerce/live/20210611/1200/20210611_120000.csv
# dim_name: marketplace, dim value: de
# dim_name: platform, dim value: mobile_web
# t: time.struct_time(tm_year=2021, tm_mon=6, tm_mday=11, tm_hour=13, tm_min=0, tm_sec=0, tm_wday=4, tm_yday=162, tm_isdst=-1)
# File name: ./data/ecommerce/live/20210611/1300/20210611_130000.csv
# dim_name: marketplace, dim value: de
# dim_name: platform, dim value: mobile_web
# t: time.struct_time(tm_year=2021, tm_mon=6, tm_mday=11, tm_hour=14, tm_min=0, tm_sec=0, tm_wday=4, tm_yday=162, tm_isdst=-1)
# File name: ./data/ecommerce/live/20210611/1400/20210611_140000.csv
# dim_name: marketplace, dim value: de
# dim_name: platform, dim value: mobile_web
# t: time.struct_time(tm_year=2021, tm_mon=6, tm_mday=11, tm_hour=15, tm_min=0, tm_sec=0, tm_wday=4, tm_yday=162, tm_isdst=-1)
# File name: ./data/ecommerce/live/20210611/1500/20210611_150000.csv
# dim_name: marketplace, dim value: de
# dim_name: platform, dim value: mobile_web
# t: time.struct_time(tm_year=2021, tm_mon=6, tm_mday=11, tm_hour=16, tm_min=0, tm_sec=0, tm_wday=4, tm_yday=162, tm_isdst=-1)
# File name: ./data/ecommerce/live/20210611/1600/20210611_160000.csv
# dim_name: marketplace, dim value: de
# dim_name: platform, dim value: mobile_web
# t: time.struct_time(tm_year=2021, tm_mon=6, tm_mday=11, tm_hour=17, tm_min=0, tm_sec=0, tm_wday=4, tm_yday=162, tm_isdst=-1)
# File name: ./data/ecommerce/live/20210611/1700/20210611_170000.csv
# dim_name: marketplace, dim value: de
# dim_name: platform, dim value: mobile_web
# t: time.struct_time(tm_year=2021, tm_mon=6, tm_mday=11, tm_hour=18, tm_min=0, tm_sec=0, tm_wday=4, tm_yday=162, tm_isdst=-1)
# File name: ./data/ecommerce/live/20210611/1800/20210611_180000.csv
# dim_name: marketplace, dim value: de
# dim_name: platform, dim value: mobile_web
# t: time.struct_time(tm_year=2021, tm_mon=6, tm_mday=11, tm_hour=19, tm_min=0, tm_sec=0, tm_wday=4, tm_yday=162, tm_isdst=-1)
# File name: ./data/ecommerce/live/20210611/1900/20210611_190000.csv
# dim_name: marketplace, dim value: de
# dim_name: platform, dim value: mobile_web
# t: time.struct_time(tm_year=2021, tm_mon=6, tm_mday=11, tm_hour=20, tm_min=0, tm_sec=0, tm_wday=4, tm_yday=162, tm_isdst=-1)
# File name: ./data/ecommerce/live/20210611/2000/20210611_200000.csv
# dim_name: marketplace, dim value: de
# dim_name: platform, dim value: mobile_web
# t: time.struct_time(tm_year=2021, tm_mon=6, tm_mday=11, tm_hour=21, tm_min=0, tm_sec=0, tm_wday=4, tm_yday=162, tm_isdst=-1)
# File name: ./data/ecommerce/live/20210611/2100/20210611_210000.csv
# dim_name: marketplace, dim value: de
# dim_name: platform, dim value: mobile_web
# t: time.struct_time(tm_year=2021, tm_mon=6, tm_mday=11, tm_hour=22, tm_min=0, tm_sec=0, tm_wday=4, tm_yday=162, tm_isdst=-1)
# File name: ./data/ecommerce/live/20210611/2200/20210611_220000.csv
# dim_name: marketplace, dim value: de
# dim_name: platform, dim value: mobile_web
# t: time.struct_time(tm_year=2021, tm_mon=6, tm_mday=11, tm_hour=23, tm_min=0, tm_sec=0, tm_wday=4, tm_yday=162, tm_isdst=-1)
# File name: ./data/ecommerce/live/20210611/2300/20210611_230000.csv
# dim_name: marketplace, dim value: de
# dim_name: platform, dim value: mobile_web
# data: {'tseriesid': '2c54c039eea29141a2d3ae44c49ce9894a32c9d75280609cbe860aa4a7c134902958542b0fbaa4736a29ddeeba750d529a6f3daf7a4a87fd92644f34cc8dad1e'}
# t: time.struct_time(tm_year=2021, tm_mon=6, tm_mday=11, tm_hour=9, tm_min=0, tm_sec=0, tm_wday=4, tm_yday=162, tm_isdst=-1)
# File name: ./data/ecommerce/live/20210611/0900/20210611_090000.csv
# dim_name: marketplace, dim value: uk
# dim_name: platform, dim value: mobile_web
# t: time.struct_time(tm_year=2021, tm_mon=6, tm_mday=11, tm_hour=10, tm_min=0, tm_sec=0, tm_wday=4, tm_yday=162, tm_isdst=-1)
# File name: ./data/ecommerce/live/20210611/1000/20210611_100000.csv
# dim_name: marketplace, dim value: uk
# dim_name: platform, dim value: mobile_web
# t: time.struct_time(tm_year=2021, tm_mon=6, tm_mday=11, tm_hour=11, tm_min=0, tm_sec=0, tm_wday=4, tm_yday=162, tm_isdst=-1)
# File name: ./data/ecommerce/live/20210611/1100/20210611_110000.csv
# dim_name: marketplace, dim value: uk
# dim_name: platform, dim value: mobile_web
# t: time.struct_time(tm_year=2021, tm_mon=6, tm_mday=11, tm_hour=12, tm_min=0, tm_sec=0, tm_wday=4, tm_yday=162, tm_isdst=-1)
# File name: ./data/ecommerce/live/20210611/1200/20210611_120000.csv
# dim_name: marketplace, dim value: uk
# dim_name: platform, dim value: mobile_web
# t: time.struct_time(tm_year=2021, tm_mon=6, tm_mday=11, tm_hour=13, tm_min=0, tm_sec=0, tm_wday=4, tm_yday=162, tm_isdst=-1)
# File name: ./data/ecommerce/live/20210611/1300/20210611_130000.csv
# dim_name: marketplace, dim value: uk
# dim_name: platform, dim value: mobile_web
# t: time.struct_time(tm_year=2021, tm_mon=6, tm_mday=11, tm_hour=14, tm_min=0, tm_sec=0, tm_wday=4, tm_yday=162, tm_isdst=-1)
# File name: ./data/ecommerce/live/20210611/1400/20210611_140000.csv
# dim_name: marketplace, dim value: uk
# dim_name: platform, dim value: mobile_web
# t: time.struct_time(tm_year=2021, tm_mon=6, tm_mday=11, tm_hour=15, tm_min=0, tm_sec=0, tm_wday=4, tm_yday=162, tm_isdst=-1)
# File name: ./data/ecommerce/live/20210611/1500/20210611_150000.csv
# dim_name: marketplace, dim value: uk
# dim_name: platform, dim value: mobile_web
# t: time.struct_time(tm_year=2021, tm_mon=6, tm_mday=11, tm_hour=16, tm_min=0, tm_sec=0, tm_wday=4, tm_yday=162, tm_isdst=-1)
# File name: ./data/ecommerce/live/20210611/1600/20210611_160000.csv
# dim_name: marketplace, dim value: uk
# dim_name: platform, dim value: mobile_web
# t: time.struct_time(tm_year=2021, tm_mon=6, tm_mday=11, tm_hour=17, tm_min=0, tm_sec=0, tm_wday=4, tm_yday=162, tm_isdst=-1)
# File name: ./data/ecommerce/live/20210611/1700/20210611_170000.csv
# dim_name: marketplace, dim value: uk
# dim_name: platform, dim value: mobile_web
# t: time.struct_time(tm_year=2021, tm_mon=6, tm_mday=11, tm_hour=18, tm_min=0, tm_sec=0, tm_wday=4, tm_yday=162, tm_isdst=-1)
# File name: ./data/ecommerce/live/20210611/1800/20210611_180000.csv
# dim_name: marketplace, dim value: uk
# dim_name: platform, dim value: mobile_web
# t: time.struct_time(tm_year=2021, tm_mon=6, tm_mday=11, tm_hour=19, tm_min=0, tm_sec=0, tm_wday=4, tm_yday=162, tm_isdst=-1)
# File name: ./data/ecommerce/live/20210611/1900/20210611_190000.csv
# dim_name: marketplace, dim value: uk
# dim_name: platform, dim value: mobile_web
# t: time.struct_time(tm_year=2021, tm_mon=6, tm_mday=11, tm_hour=20, tm_min=0, tm_sec=0, tm_wday=4, tm_yday=162, tm_isdst=-1)
# File name: ./data/ecommerce/live/20210611/2000/20210611_200000.csv
# dim_name: marketplace, dim value: uk
# dim_name: platform, dim value: mobile_web
# t: time.struct_time(tm_year=2021, tm_mon=6, tm_mday=11, tm_hour=21, tm_min=0, tm_sec=0, tm_wday=4, tm_yday=162, tm_isdst=-1)
# File name: ./data/ecommerce/live/20210611/2100/20210611_210000.csv
# dim_name: marketplace, dim value: uk
# dim_name: platform, dim value: mobile_web
# t: time.struct_time(tm_year=2021, tm_mon=6, tm_mday=11, tm_hour=22, tm_min=0, tm_sec=0, tm_wday=4, tm_yday=162, tm_isdst=-1)
# File name: ./data/ecommerce/live/20210611/2200/20210611_220000.csv
# dim_name: marketplace, dim value: uk
# dim_name: platform, dim value: mobile_web
# t: time.struct_time(tm_year=2021, tm_mon=6, tm_mday=11, tm_hour=23, tm_min=0, tm_sec=0, tm_wday=4, tm_yday=162, tm_isdst=-1)
# File name: ./data/ecommerce/live/20210611/2300/20210611_230000.csv
# dim_name: marketplace, dim value: uk
# dim_name: platform, dim value: mobile_web
#
#
#
# {'AnomalyGroupId': 'c6c9ef45-8c59-4676-91ee-8193f45f7357',
#  'AnomalyGroupScore': 86.78,
#  'EndTime': '2021-06-11T13:00Z[UTC]',
#  'PrimaryMetricName': 'revenue',
#  'StartTime': '2021-06-11T12:00Z[UTC]'}
# data: {'tseriesid': '806ed8e77d183d791ea7e239568f7466fa0150f5c5e195f661db6fb2fb6d875ce9f21a3ff024830c6d4a6e5a0eea32211b772d217e5d708d59be320fcb1f6793'}
# t: time.struct_time(tm_year=2021, tm_mon=6, tm_mday=11, tm_hour=12, tm_min=0, tm_sec=0, tm_wday=4, tm_yday=162, tm_isdst=-1)
# File name: ./data/ecommerce/live/20210611/1200/20210611_120000.csv
# dim_name: marketplace, dim value: jp
# dim_name: platform, dim value: mobile_web
# t: time.struct_time(tm_year=2021, tm_mon=6, tm_mday=11, tm_hour=13, tm_min=0, tm_sec=0, tm_wday=4, tm_yday=162, tm_isdst=-1)
# File name: ./data/ecommerce/live/20210611/1300/20210611_130000.csv
# dim_name: marketplace, dim value: jp
# dim_name: platform, dim value: mobile_web
# data: {'tseriesid': 'ae6a56fa750ccb9aaf2e19e03c9bf443677eddab1146cdac2004109b2beb9a1fcccb2902871a9f3a9c87d1b166f710509f2feccfd4b36dbbb292a0345e353bd2'}
# t: time.struct_time(tm_year=2021, tm_mon=6, tm_mday=11, tm_hour=12, tm_min=0, tm_sec=0, tm_wday=4, tm_yday=162, tm_isdst=-1)
# File name: ./data/ecommerce/live/20210611/1200/20210611_120000.csv
# dim_name: marketplace, dim value: de
# dim_name: platform, dim value: pc_web
# t: time.struct_time(tm_year=2021, tm_mon=6, tm_mday=11, tm_hour=13, tm_min=0, tm_sec=0, tm_wday=4, tm_yday=162, tm_isdst=-1)
# File name: ./data/ecommerce/live/20210611/1300/20210611_130000.csv
# dim_name: marketplace, dim value: de
# dim_name: platform, dim value: pc_web
# data: {'tseriesid': 'f2762c3d8bfd7a091b6c00fd13b8f75ee4a488038c84f161b9024062ef721a7c1f6c0196309a6783c59f76f6ca2f155614b0873f94a9dae01af684a8c164c1b2'}
# t: time.struct_time(tm_year=2021, tm_mon=6, tm_mday=11, tm_hour=12, tm_min=0, tm_sec=0, tm_wday=4, tm_yday=162, tm_isdst=-1)
# File name: ./data/ecommerce/live/20210611/1200/20210611_120000.csv
# dim_name: marketplace, dim value: es
# dim_name: platform, dim value: mobile_web
# t: time.struct_time(tm_year=2021, tm_mon=6, tm_mday=11, tm_hour=13, tm_min=0, tm_sec=0, tm_wday=4, tm_yday=162, tm_isdst=-1)
# File name: ./data/ecommerce/live/20210611/1300/20210611_130000.csv
# dim_name: marketplace, dim value: es
# dim_name: platform, dim value: mobile_web
# data: {'tseriesid': '01982cf679fe2eb34d34b2bb81b9cc70ca5705f5357da7a47172cb5bc71f7cdc0c656ab6cb4d2e38bc96106490ae2d2351756b069b289eabab00f53cb0c2367f'}
# t: time.struct_time(tm_year=2021, tm_mon=6, tm_mday=11, tm_hour=12, tm_min=0, tm_sec=0, tm_wday=4, tm_yday=162, tm_isdst=-1)
# File name: ./data/ecommerce/live/20210611/1200/20210611_120000.csv
# dim_name: marketplace, dim value: de
# dim_name: platform, dim value: mobile_web
# t: time.struct_time(tm_year=2021, tm_mon=6, tm_mday=11, tm_hour=13, tm_min=0, tm_sec=0, tm_wday=4, tm_yday=162, tm_isdst=-1)
# File name: ./data/ecommerce/live/20210611/1300/20210611_130000.csv
# dim_name: marketplace, dim value: de
# dim_name: platform, dim value: mobile_web
# data: {'tseriesid': '2c54c039eea29141a2d3ae44c49ce9894a32c9d75280609cbe860aa4a7c134902958542b0fbaa4736a29ddeeba750d529a6f3daf7a4a87fd92644f34cc8dad1e'}
# t: time.struct_time(tm_year=2021, tm_mon=6, tm_mday=11, tm_hour=12, tm_min=0, tm_sec=0, tm_wday=4, tm_yday=162, tm_isdst=-1)
# File name: ./data/ecommerce/live/20210611/1200/20210611_120000.csv
# dim_name: marketplace, dim value: uk
# dim_name: platform, dim value: mobile_web
# t: time.struct_time(tm_year=2021, tm_mon=6, tm_mday=11, tm_hour=13, tm_min=0, tm_sec=0, tm_wday=4, tm_yday=162, tm_isdst=-1)
# File name: ./data/ecommerce/live/20210611/1300/20210611_130000.csv
# dim_name: marketplace, dim value: uk
# dim_name: platform, dim value: mobile_web
# data: {'tseriesid': 'd8ee40de893e6be62336ce71df8d9d018d85e0467712ab6d612f283192c8fa3a7b3901dbc631f8bb41a8fa4c5e6ff10caa47ea20fb958a5460474753f18e3b9c'}
# t: time.struct_time(tm_year=2021, tm_mon=6, tm_mday=11, tm_hour=12, tm_min=0, tm_sec=0, tm_wday=4, tm_yday=162, tm_isdst=-1)
# File name: ./data/ecommerce/live/20210611/1200/20210611_120000.csv
# dim_name: marketplace, dim value: us
# dim_name: platform, dim value: mobile_app
# t: time.struct_time(tm_year=2021, tm_mon=6, tm_mday=11, tm_hour=13, tm_min=0, tm_sec=0, tm_wday=4, tm_yday=162, tm_isdst=-1)
# File name: ./data/ecommerce/live/20210611/1300/20210611_130000.csv
# dim_name: marketplace, dim value: us
# dim_name: platform, dim value: mobile_app
# data: {'tseriesid': 'b385abcb02d24849b06c187b144311d2ec04f91f123066d2415c7b66d2364a7e36083c145d5ae9d39b6f3633316238c6ba0d14e851b9fd85cb429ae9433fd68e'}
# t: time.struct_time(tm_year=2021, tm_mon=6, tm_mday=11, tm_hour=12, tm_min=0, tm_sec=0, tm_wday=4, tm_yday=162, tm_isdst=-1)
# File name: ./data/ecommerce/live/20210611/1200/20210611_120000.csv
# dim_name: marketplace, dim value: it
# dim_name: platform, dim value: pc_web
# t: time.struct_time(tm_year=2021, tm_mon=6, tm_mday=11, tm_hour=13, tm_min=0, tm_sec=0, tm_wday=4, tm_yday=162, tm_isdst=-1)
# File name: ./data/ecommerce/live/20210611/1300/20210611_130000.csv
# dim_name: marketplace, dim value: it
# dim_name: platform, dim value: pc_web
#
#
#
# {'AnomalyGroupId': '093a06b5-60ca-4d93-a687-93e2838047d3',
#  'AnomalyGroupScore': 86.78,
#  'EndTime': '2021-06-11T11:00Z[UTC]',
#  'PrimaryMetricName': 'revenue',
#  'StartTime': '2021-06-11T11:00Z[UTC]'}
# data: {'tseriesid': '806ed8e77d183d791ea7e239568f7466fa0150f5c5e195f661db6fb2fb6d875ce9f21a3ff024830c6d4a6e5a0eea32211b772d217e5d708d59be320fcb1f6793'}
# t: time.struct_time(tm_year=2021, tm_mon=6, tm_mday=11, tm_hour=11, tm_min=0, tm_sec=0, tm_wday=4, tm_yday=162, tm_isdst=-1)
# File name: ./data/ecommerce/live/20210611/1100/20210611_110000.csv
# dim_name: marketplace, dim value: jp
# dim_name: platform, dim value: mobile_web
# data: {'tseriesid': 'ae6a56fa750ccb9aaf2e19e03c9bf443677eddab1146cdac2004109b2beb9a1fcccb2902871a9f3a9c87d1b166f710509f2feccfd4b36dbbb292a0345e353bd2'}
# t: time.struct_time(tm_year=2021, tm_mon=6, tm_mday=11, tm_hour=11, tm_min=0, tm_sec=0, tm_wday=4, tm_yday=162, tm_isdst=-1)
# File name: ./data/ecommerce/live/20210611/1100/20210611_110000.csv
# dim_name: marketplace, dim value: de
# dim_name: platform, dim value: pc_web
# data: {'tseriesid': 'f2762c3d8bfd7a091b6c00fd13b8f75ee4a488038c84f161b9024062ef721a7c1f6c0196309a6783c59f76f6ca2f155614b0873f94a9dae01af684a8c164c1b2'}
# t: time.struct_time(tm_year=2021, tm_mon=6, tm_mday=11, tm_hour=11, tm_min=0, tm_sec=0, tm_wday=4, tm_yday=162, tm_isdst=-1)
# File name: ./data/ecommerce/live/20210611/1100/20210611_110000.csv
# dim_name: marketplace, dim value: es
# dim_name: platform, dim value: mobile_web
# data: {'tseriesid': '01982cf679fe2eb34d34b2bb81b9cc70ca5705f5357da7a47172cb5bc71f7cdc0c656ab6cb4d2e38bc96106490ae2d2351756b069b289eabab00f53cb0c2367f'}
# t: time.struct_time(tm_year=2021, tm_mon=6, tm_mday=11, tm_hour=11, tm_min=0, tm_sec=0, tm_wday=4, tm_yday=162, tm_isdst=-1)
# File name: ./data/ecommerce/live/20210611/1100/20210611_110000.csv
# dim_name: marketplace, dim value: de
# dim_name: platform, dim value: mobile_web
# data: {'tseriesid': '2c54c039eea29141a2d3ae44c49ce9894a32c9d75280609cbe860aa4a7c134902958542b0fbaa4736a29ddeeba750d529a6f3daf7a4a87fd92644f34cc8dad1e'}
# t: time.struct_time(tm_year=2021, tm_mon=6, tm_mday=11, tm_hour=11, tm_min=0, tm_sec=0, tm_wday=4, tm_yday=162, tm_isdst=-1)
# File name: ./data/ecommerce/live/20210611/1100/20210611_110000.csv
# dim_name: marketplace, dim value: uk
# dim_name: platform, dim value: mobile_web
# data: {'tseriesid': 'd8ee40de893e6be62336ce71df8d9d018d85e0467712ab6d612f283192c8fa3a7b3901dbc631f8bb41a8fa4c5e6ff10caa47ea20fb958a5460474753f18e3b9c'}
# t: time.struct_time(tm_year=2021, tm_mon=6, tm_mday=11, tm_hour=11, tm_min=0, tm_sec=0, tm_wday=4, tm_yday=162, tm_isdst=-1)
# File name: ./data/ecommerce/live/20210611/1100/20210611_110000.csv
# dim_name: marketplace, dim value: us
# dim_name: platform, dim value: mobile_app
# data: {'tseriesid': 'b385abcb02d24849b06c187b144311d2ec04f91f123066d2415c7b66d2364a7e36083c145d5ae9d39b6f3633316238c6ba0d14e851b9fd85cb429ae9433fd68e'}
# t: time.struct_time(tm_year=2021, tm_mon=6, tm_mday=11, tm_hour=11, tm_min=0, tm_sec=0, tm_wday=4, tm_yday=162, tm_isdst=-1)
# File name: ./data/ecommerce/live/20210611/1100/20210611_110000.csv
# dim_name: marketplace, dim value: it
# dim_name: platform, dim value: pc_web
# data: {'tseriesid': 'd8ee40de893e6be62336ce71df8d9d018d85e0467712ab6d612f283192c8fa3a7b3901dbc631f8bb41a8fa4c5e6ff10caa47ea20fb958a5460474753f18e3b9c'}
# t: time.struct_time(tm_year=2021, tm_mon=6, tm_mday=11, tm_hour=11, tm_min=0, tm_sec=0, tm_wday=4, tm_yday=162, tm_isdst=-1)
# File name: ./data/ecommerce/live/20210611/1100/20210611_110000.csv
# dim_name: marketplace, dim value: us
# dim_name: platform, dim value: mobile_app
#
#
#
# {'AnomalyGroupId': '51fa1473-3d49-4c52-bafc-217d779a762b',
#  'AnomalyGroupScore': 86.78,
#  'EndTime': '2021-06-11T10:00Z[UTC]',
#  'PrimaryMetricName': 'revenue',
#  'StartTime': '2021-06-11T10:00Z[UTC]'}
# data: {'tseriesid': '806ed8e77d183d791ea7e239568f7466fa0150f5c5e195f661db6fb2fb6d875ce9f21a3ff024830c6d4a6e5a0eea32211b772d217e5d708d59be320fcb1f6793'}
# t: time.struct_time(tm_year=2021, tm_mon=6, tm_mday=11, tm_hour=10, tm_min=0, tm_sec=0, tm_wday=4, tm_yday=162, tm_isdst=-1)
# File name: ./data/ecommerce/live/20210611/1000/20210611_100000.csv
# dim_name: marketplace, dim value: jp
# dim_name: platform, dim value: mobile_web
# data: {'tseriesid': 'ae6a56fa750ccb9aaf2e19e03c9bf443677eddab1146cdac2004109b2beb9a1fcccb2902871a9f3a9c87d1b166f710509f2feccfd4b36dbbb292a0345e353bd2'}
# t: time.struct_time(tm_year=2021, tm_mon=6, tm_mday=11, tm_hour=10, tm_min=0, tm_sec=0, tm_wday=4, tm_yday=162, tm_isdst=-1)
# File name: ./data/ecommerce/live/20210611/1000/20210611_100000.csv
# dim_name: marketplace, dim value: de
# dim_name: platform, dim value: pc_web
# data: {'tseriesid': 'f2762c3d8bfd7a091b6c00fd13b8f75ee4a488038c84f161b9024062ef721a7c1f6c0196309a6783c59f76f6ca2f155614b0873f94a9dae01af684a8c164c1b2'}
# t: time.struct_time(tm_year=2021, tm_mon=6, tm_mday=11, tm_hour=10, tm_min=0, tm_sec=0, tm_wday=4, tm_yday=162, tm_isdst=-1)
# File name: ./data/ecommerce/live/20210611/1000/20210611_100000.csv
# dim_name: marketplace, dim value: es
# dim_name: platform, dim value: mobile_web
# data: {'tseriesid': '01982cf679fe2eb34d34b2bb81b9cc70ca5705f5357da7a47172cb5bc71f7cdc0c656ab6cb4d2e38bc96106490ae2d2351756b069b289eabab00f53cb0c2367f'}
# t: time.struct_time(tm_year=2021, tm_mon=6, tm_mday=11, tm_hour=10, tm_min=0, tm_sec=0, tm_wday=4, tm_yday=162, tm_isdst=-1)
# File name: ./data/ecommerce/live/20210611/1000/20210611_100000.csv
# dim_name: marketplace, dim value: de
# dim_name: platform, dim value: mobile_web
# data: {'tseriesid': '2c54c039eea29141a2d3ae44c49ce9894a32c9d75280609cbe860aa4a7c134902958542b0fbaa4736a29ddeeba750d529a6f3daf7a4a87fd92644f34cc8dad1e'}
# t: time.struct_time(tm_year=2021, tm_mon=6, tm_mday=11, tm_hour=10, tm_min=0, tm_sec=0, tm_wday=4, tm_yday=162, tm_isdst=-1)
# File name: ./data/ecommerce/live/20210611/1000/20210611_100000.csv
# dim_name: marketplace, dim value: uk
# dim_name: platform, dim value: mobile_web
# data: {'tseriesid': 'd8ee40de893e6be62336ce71df8d9d018d85e0467712ab6d612f283192c8fa3a7b3901dbc631f8bb41a8fa4c5e6ff10caa47ea20fb958a5460474753f18e3b9c'}
# t: time.struct_time(tm_year=2021, tm_mon=6, tm_mday=11, tm_hour=10, tm_min=0, tm_sec=0, tm_wday=4, tm_yday=162, tm_isdst=-1)
# File name: ./data/ecommerce/live/20210611/1000/20210611_100000.csv
# dim_name: marketplace, dim value: us
# dim_name: platform, dim value: mobile_app
# data: {'tseriesid': 'b385abcb02d24849b06c187b144311d2ec04f91f123066d2415c7b66d2364a7e36083c145d5ae9d39b6f3633316238c6ba0d14e851b9fd85cb429ae9433fd68e'}
# t: time.struct_time(tm_year=2021, tm_mon=6, tm_mday=11, tm_hour=10, tm_min=0, tm_sec=0, tm_wday=4, tm_yday=162, tm_isdst=-1)
# File name: ./data/ecommerce/live/20210611/1000/20210611_100000.csv
# dim_name: marketplace, dim value: it
# dim_name: platform, dim value: pc_web
# data: {'tseriesid': 'd8ee40de893e6be62336ce71df8d9d018d85e0467712ab6d612f283192c8fa3a7b3901dbc631f8bb41a8fa4c5e6ff10caa47ea20fb958a5460474753f18e3b9c'}
# t: time.struct_time(tm_year=2021, tm_mon=6, tm_mday=11, tm_hour=10, tm_min=0, tm_sec=0, tm_wday=4, tm_yday=162, tm_isdst=-1)
# File name: ./data/ecommerce/live/20210611/1000/20210611_100000.csv
# dim_name: marketplace, dim value: us
# dim_name: platform, dim value: mobile_app
# data: {'tseriesid': 'd8ee40de893e6be62336ce71df8d9d018d85e0467712ab6d612f283192c8fa3a7b3901dbc631f8bb41a8fa4c5e6ff10caa47ea20fb958a5460474753f18e3b9c'}
# t: time.struct_time(tm_year=2021, tm_mon=6, tm_mday=11, tm_hour=10, tm_min=0, tm_sec=0, tm_wday=4, tm_yday=162, tm_isdst=-1)
# File name: ./data/ecommerce/live/20210611/1000/20210611_100000.csv
# dim_name: marketplace, dim value: us
# dim_name: platform, dim value: mobile_app
# data: {'tseriesid': 'b385abcb02d24849b06c187b144311d2ec04f91f123066d2415c7b66d2364a7e36083c145d5ae9d39b6f3633316238c6ba0d14e851b9fd85cb429ae9433fd68e'}
# t: time.struct_time(tm_year=2021, tm_mon=6, tm_mday=11, tm_hour=10, tm_min=0, tm_sec=0, tm_wday=4, tm_yday=162, tm_isdst=-1)
# File name: ./data/ecommerce/live/20210611/1000/20210611_100000.csv
# dim_name: marketplace, dim value: it
# dim_name: platform, dim value: pc_web
#
#
#
# {'AnomalyGroupId': '8bcf8de1-6f82-4272-a822-5b1cc2a5b1a0',
#  'AnomalyGroupScore': 100.0,
#  'EndTime': '2021-06-11T02:00Z[UTC]',
#  'PrimaryMetricName': 'views',
#  'StartTime': '2021-06-10T17:00Z[UTC]'}
# data: {'tseriesid': '806ed8e77d183d791ea7e239568f7466fa0150f5c5e195f661db6fb2fb6d875ce9f21a3ff024830c6d4a6e5a0eea32211b772d217e5d708d59be320fcb1f6793'}
# t: time.struct_time(tm_year=2021, tm_mon=6, tm_mday=10, tm_hour=17, tm_min=0, tm_sec=0, tm_wday=3, tm_yday=161, tm_isdst=-1)
# File name: ./data/ecommerce/live/20210610/1700/20210610_170000.csv
# dim_name: marketplace, dim value: jp
# dim_name: platform, dim value: mobile_web
# t: time.struct_time(tm_year=2021, tm_mon=6, tm_mday=10, tm_hour=18, tm_min=0, tm_sec=0, tm_wday=3, tm_yday=161, tm_isdst=-1)
# File name: ./data/ecommerce/live/20210610/1800/20210610_180000.csv
# dim_name: marketplace, dim value: jp
# dim_name: platform, dim value: mobile_web
# t: time.struct_time(tm_year=2021, tm_mon=6, tm_mday=10, tm_hour=19, tm_min=0, tm_sec=0, tm_wday=3, tm_yday=161, tm_isdst=-1)
# File name: ./data/ecommerce/live/20210610/1900/20210610_190000.csv
# dim_name: marketplace, dim value: jp
# dim_name: platform, dim value: mobile_web
# t: time.struct_time(tm_year=2021, tm_mon=6, tm_mday=10, tm_hour=20, tm_min=0, tm_sec=0, tm_wday=3, tm_yday=161, tm_isdst=-1)
# File name: ./data/ecommerce/live/20210610/2000/20210610_200000.csv
# dim_name: marketplace, dim value: jp
# dim_name: platform, dim value: mobile_web
# t: time.struct_time(tm_year=2021, tm_mon=6, tm_mday=10, tm_hour=21, tm_min=0, tm_sec=0, tm_wday=3, tm_yday=161, tm_isdst=-1)
# File name: ./data/ecommerce/live/20210610/2100/20210610_210000.csv
# dim_name: marketplace, dim value: jp
# dim_name: platform, dim value: mobile_web
# t: time.struct_time(tm_year=2021, tm_mon=6, tm_mday=10, tm_hour=22, tm_min=0, tm_sec=0, tm_wday=3, tm_yday=161, tm_isdst=-1)
# File name: ./data/ecommerce/live/20210610/2200/20210610_220000.csv
# dim_name: marketplace, dim value: jp
# dim_name: platform, dim value: mobile_web
# t: time.struct_time(tm_year=2021, tm_mon=6, tm_mday=10, tm_hour=23, tm_min=0, tm_sec=0, tm_wday=3, tm_yday=161, tm_isdst=-1)
# File name: ./data/ecommerce/live/20210610/2300/20210610_230000.csv
# dim_name: marketplace, dim value: jp
# dim_name: platform, dim value: mobile_web
# t: time.struct_time(tm_year=2021, tm_mon=6, tm_mday=11, tm_hour=0, tm_min=0, tm_sec=0, tm_wday=4, tm_yday=162, tm_isdst=-1)
# File name: ./data/ecommerce/live/20210611/0000/20210611_000000.csv
# dim_name: marketplace, dim value: jp
# dim_name: platform, dim value: mobile_web
# t: time.struct_time(tm_year=2021, tm_mon=6, tm_mday=11, tm_hour=1, tm_min=0, tm_sec=0, tm_wday=4, tm_yday=162, tm_isdst=-1)
# File name: ./data/ecommerce/live/20210611/0100/20210611_010000.csv
# dim_name: marketplace, dim value: jp
# dim_name: platform, dim value: mobile_web
# t: time.struct_time(tm_year=2021, tm_mon=6, tm_mday=11, tm_hour=2, tm_min=0, tm_sec=0, tm_wday=4, tm_yday=162, tm_isdst=-1)
# File name: ./data/ecommerce/live/20210611/0200/20210611_020000.csv
# dim_name: marketplace, dim value: jp
# dim_name: platform, dim value: mobile_web
# data: {'tseriesid': 'ae6a56fa750ccb9aaf2e19e03c9bf443677eddab1146cdac2004109b2beb9a1fcccb2902871a9f3a9c87d1b166f710509f2feccfd4b36dbbb292a0345e353bd2'}
# t: time.struct_time(tm_year=2021, tm_mon=6, tm_mday=10, tm_hour=17, tm_min=0, tm_sec=0, tm_wday=3, tm_yday=161, tm_isdst=-1)
# File name: ./data/ecommerce/live/20210610/1700/20210610_170000.csv
# dim_name: marketplace, dim value: de
# dim_name: platform, dim value: pc_web
# t: time.struct_time(tm_year=2021, tm_mon=6, tm_mday=10, tm_hour=18, tm_min=0, tm_sec=0, tm_wday=3, tm_yday=161, tm_isdst=-1)
# File name: ./data/ecommerce/live/20210610/1800/20210610_180000.csv
# dim_name: marketplace, dim value: de
# dim_name: platform, dim value: pc_web
# t: time.struct_time(tm_year=2021, tm_mon=6, tm_mday=10, tm_hour=19, tm_min=0, tm_sec=0, tm_wday=3, tm_yday=161, tm_isdst=-1)
# File name: ./data/ecommerce/live/20210610/1900/20210610_190000.csv
# dim_name: marketplace, dim value: de
# dim_name: platform, dim value: pc_web
# t: time.struct_time(tm_year=2021, tm_mon=6, tm_mday=10, tm_hour=20, tm_min=0, tm_sec=0, tm_wday=3, tm_yday=161, tm_isdst=-1)
# File name: ./data/ecommerce/live/20210610/2000/20210610_200000.csv
# dim_name: marketplace, dim value: de
# dim_name: platform, dim value: pc_web
# t: time.struct_time(tm_year=2021, tm_mon=6, tm_mday=10, tm_hour=21, tm_min=0, tm_sec=0, tm_wday=3, tm_yday=161, tm_isdst=-1)
# File name: ./data/ecommerce/live/20210610/2100/20210610_210000.csv
# dim_name: marketplace, dim value: de
# dim_name: platform, dim value: pc_web
# t: time.struct_time(tm_year=2021, tm_mon=6, tm_mday=10, tm_hour=22, tm_min=0, tm_sec=0, tm_wday=3, tm_yday=161, tm_isdst=-1)
# File name: ./data/ecommerce/live/20210610/2200/20210610_220000.csv
# dim_name: marketplace, dim value: de
# dim_name: platform, dim value: pc_web
# t: time.struct_time(tm_year=2021, tm_mon=6, tm_mday=10, tm_hour=23, tm_min=0, tm_sec=0, tm_wday=3, tm_yday=161, tm_isdst=-1)
# File name: ./data/ecommerce/live/20210610/2300/20210610_230000.csv
# dim_name: marketplace, dim value: de
# dim_name: platform, dim value: pc_web
# t: time.struct_time(tm_year=2021, tm_mon=6, tm_mday=11, tm_hour=0, tm_min=0, tm_sec=0, tm_wday=4, tm_yday=162, tm_isdst=-1)
# File name: ./data/ecommerce/live/20210611/0000/20210611_000000.csv
# dim_name: marketplace, dim value: de
# dim_name: platform, dim value: pc_web
# t: time.struct_time(tm_year=2021, tm_mon=6, tm_mday=11, tm_hour=1, tm_min=0, tm_sec=0, tm_wday=4, tm_yday=162, tm_isdst=-1)
# File name: ./data/ecommerce/live/20210611/0100/20210611_010000.csv
# dim_name: marketplace, dim value: de
# dim_name: platform, dim value: pc_web
# t: time.struct_time(tm_year=2021, tm_mon=6, tm_mday=11, tm_hour=2, tm_min=0, tm_sec=0, tm_wday=4, tm_yday=162, tm_isdst=-1)
# File name: ./data/ecommerce/live/20210611/0200/20210611_020000.csv
# dim_name: marketplace, dim value: de
# dim_name: platform, dim value: pc_web
# data: {'tseriesid': 'f2762c3d8bfd7a091b6c00fd13b8f75ee4a488038c84f161b9024062ef721a7c1f6c0196309a6783c59f76f6ca2f155614b0873f94a9dae01af684a8c164c1b2'}
# t: time.struct_time(tm_year=2021, tm_mon=6, tm_mday=10, tm_hour=17, tm_min=0, tm_sec=0, tm_wday=3, tm_yday=161, tm_isdst=-1)
# File name: ./data/ecommerce/live/20210610/1700/20210610_170000.csv
# dim_name: marketplace, dim value: es
# dim_name: platform, dim value: mobile_web
# t: time.struct_time(tm_year=2021, tm_mon=6, tm_mday=10, tm_hour=18, tm_min=0, tm_sec=0, tm_wday=3, tm_yday=161, tm_isdst=-1)
# File name: ./data/ecommerce/live/20210610/1800/20210610_180000.csv
# dim_name: marketplace, dim value: es
# dim_name: platform, dim value: mobile_web
# t: time.struct_time(tm_year=2021, tm_mon=6, tm_mday=10, tm_hour=19, tm_min=0, tm_sec=0, tm_wday=3, tm_yday=161, tm_isdst=-1)
# File name: ./data/ecommerce/live/20210610/1900/20210610_190000.csv
# dim_name: marketplace, dim value: es
# dim_name: platform, dim value: mobile_web
# t: time.struct_time(tm_year=2021, tm_mon=6, tm_mday=10, tm_hour=20, tm_min=0, tm_sec=0, tm_wday=3, tm_yday=161, tm_isdst=-1)
# File name: ./data/ecommerce/live/20210610/2000/20210610_200000.csv
# dim_name: marketplace, dim value: es
# dim_name: platform, dim value: mobile_web
# t: time.struct_time(tm_year=2021, tm_mon=6, tm_mday=10, tm_hour=21, tm_min=0, tm_sec=0, tm_wday=3, tm_yday=161, tm_isdst=-1)
# File name: ./data/ecommerce/live/20210610/2100/20210610_210000.csv
# dim_name: marketplace, dim value: es
# dim_name: platform, dim value: mobile_web
# t: time.struct_time(tm_year=2021, tm_mon=6, tm_mday=10, tm_hour=22, tm_min=0, tm_sec=0, tm_wday=3, tm_yday=161, tm_isdst=-1)
# File name: ./data/ecommerce/live/20210610/2200/20210610_220000.csv
# dim_name: marketplace, dim value: es
# dim_name: platform, dim value: mobile_web
# t: time.struct_time(tm_year=2021, tm_mon=6, tm_mday=10, tm_hour=23, tm_min=0, tm_sec=0, tm_wday=3, tm_yday=161, tm_isdst=-1)
# File name: ./data/ecommerce/live/20210610/2300/20210610_230000.csv
# dim_name: marketplace, dim value: es
# dim_name: platform, dim value: mobile_web
# t: time.struct_time(tm_year=2021, tm_mon=6, tm_mday=11, tm_hour=0, tm_min=0, tm_sec=0, tm_wday=4, tm_yday=162, tm_isdst=-1)
# File name: ./data/ecommerce/live/20210611/0000/20210611_000000.csv
# dim_name: marketplace, dim value: es
# dim_name: platform, dim value: mobile_web
# t: time.struct_time(tm_year=2021, tm_mon=6, tm_mday=11, tm_hour=1, tm_min=0, tm_sec=0, tm_wday=4, tm_yday=162, tm_isdst=-1)
# File name: ./data/ecommerce/live/20210611/0100/20210611_010000.csv
# dim_name: marketplace, dim value: es
# dim_name: platform, dim value: mobile_web
# t: time.struct_time(tm_year=2021, tm_mon=6, tm_mday=11, tm_hour=2, tm_min=0, tm_sec=0, tm_wday=4, tm_yday=162, tm_isdst=-1)
# File name: ./data/ecommerce/live/20210611/0200/20210611_020000.csv
# dim_name: marketplace, dim value: es
# dim_name: platform, dim value: mobile_web
# data: {'tseriesid': '01982cf679fe2eb34d34b2bb81b9cc70ca5705f5357da7a47172cb5bc71f7cdc0c656ab6cb4d2e38bc96106490ae2d2351756b069b289eabab00f53cb0c2367f'}
# t: time.struct_time(tm_year=2021, tm_mon=6, tm_mday=10, tm_hour=17, tm_min=0, tm_sec=0, tm_wday=3, tm_yday=161, tm_isdst=-1)
# File name: ./data/ecommerce/live/20210610/1700/20210610_170000.csv
# dim_name: marketplace, dim value: de
# dim_name: platform, dim value: mobile_web
# t: time.struct_time(tm_year=2021, tm_mon=6, tm_mday=10, tm_hour=18, tm_min=0, tm_sec=0, tm_wday=3, tm_yday=161, tm_isdst=-1)
# File name: ./data/ecommerce/live/20210610/1800/20210610_180000.csv
# dim_name: marketplace, dim value: de
# dim_name: platform, dim value: mobile_web
# t: time.struct_time(tm_year=2021, tm_mon=6, tm_mday=10, tm_hour=19, tm_min=0, tm_sec=0, tm_wday=3, tm_yday=161, tm_isdst=-1)
# File name: ./data/ecommerce/live/20210610/1900/20210610_190000.csv
# dim_name: marketplace, dim value: de
# dim_name: platform, dim value: mobile_web
# t: time.struct_time(tm_year=2021, tm_mon=6, tm_mday=10, tm_hour=20, tm_min=0, tm_sec=0, tm_wday=3, tm_yday=161, tm_isdst=-1)
# File name: ./data/ecommerce/live/20210610/2000/20210610_200000.csv
# dim_name: marketplace, dim value: de
# dim_name: platform, dim value: mobile_web
# t: time.struct_time(tm_year=2021, tm_mon=6, tm_mday=10, tm_hour=21, tm_min=0, tm_sec=0, tm_wday=3, tm_yday=161, tm_isdst=-1)
# File name: ./data/ecommerce/live/20210610/2100/20210610_210000.csv
# dim_name: marketplace, dim value: de
# dim_name: platform, dim value: mobile_web
# t: time.struct_time(tm_year=2021, tm_mon=6, tm_mday=10, tm_hour=22, tm_min=0, tm_sec=0, tm_wday=3, tm_yday=161, tm_isdst=-1)
# File name: ./data/ecommerce/live/20210610/2200/20210610_220000.csv
# dim_name: marketplace, dim value: de
# dim_name: platform, dim value: mobile_web
# t: time.struct_time(tm_year=2021, tm_mon=6, tm_mday=10, tm_hour=23, tm_min=0, tm_sec=0, tm_wday=3, tm_yday=161, tm_isdst=-1)
# File name: ./data/ecommerce/live/20210610/2300/20210610_230000.csv
# dim_name: marketplace, dim value: de
# dim_name: platform, dim value: mobile_web
# t: time.struct_time(tm_year=2021, tm_mon=6, tm_mday=11, tm_hour=0, tm_min=0, tm_sec=0, tm_wday=4, tm_yday=162, tm_isdst=-1)
# File name: ./data/ecommerce/live/20210611/0000/20210611_000000.csv
# dim_name: marketplace, dim value: de
# dim_name: platform, dim value: mobile_web
# t: time.struct_time(tm_year=2021, tm_mon=6, tm_mday=11, tm_hour=1, tm_min=0, tm_sec=0, tm_wday=4, tm_yday=162, tm_isdst=-1)
# File name: ./data/ecommerce/live/20210611/0100/20210611_010000.csv
# dim_name: marketplace, dim value: de
# dim_name: platform, dim value: mobile_web
# t: time.struct_time(tm_year=2021, tm_mon=6, tm_mday=11, tm_hour=2, tm_min=0, tm_sec=0, tm_wday=4, tm_yday=162, tm_isdst=-1)
# File name: ./data/ecommerce/live/20210611/0200/20210611_020000.csv
# dim_name: marketplace, dim value: de
# dim_name: platform, dim value: mobile_web
# data: {'tseriesid': '2c54c039eea29141a2d3ae44c49ce9894a32c9d75280609cbe860aa4a7c134902958542b0fbaa4736a29ddeeba750d529a6f3daf7a4a87fd92644f34cc8dad1e'}
# t: time.struct_time(tm_year=2021, tm_mon=6, tm_mday=10, tm_hour=17, tm_min=0, tm_sec=0, tm_wday=3, tm_yday=161, tm_isdst=-1)
# File name: ./data/ecommerce/live/20210610/1700/20210610_170000.csv
# dim_name: marketplace, dim value: uk
# dim_name: platform, dim value: mobile_web
# t: time.struct_time(tm_year=2021, tm_mon=6, tm_mday=10, tm_hour=18, tm_min=0, tm_sec=0, tm_wday=3, tm_yday=161, tm_isdst=-1)
# File name: ./data/ecommerce/live/20210610/1800/20210610_180000.csv
# dim_name: marketplace, dim value: uk
# dim_name: platform, dim value: mobile_web
# t: time.struct_time(tm_year=2021, tm_mon=6, tm_mday=10, tm_hour=19, tm_min=0, tm_sec=0, tm_wday=3, tm_yday=161, tm_isdst=-1)
# File name: ./data/ecommerce/live/20210610/1900/20210610_190000.csv
# dim_name: marketplace, dim value: uk
# dim_name: platform, dim value: mobile_web
# t: time.struct_time(tm_year=2021, tm_mon=6, tm_mday=10, tm_hour=20, tm_min=0, tm_sec=0, tm_wday=3, tm_yday=161, tm_isdst=-1)
# File name: ./data/ecommerce/live/20210610/2000/20210610_200000.csv
# dim_name: marketplace, dim value: uk
# dim_name: platform, dim value: mobile_web
# t: time.struct_time(tm_year=2021, tm_mon=6, tm_mday=10, tm_hour=21, tm_min=0, tm_sec=0, tm_wday=3, tm_yday=161, tm_isdst=-1)
# File name: ./data/ecommerce/live/20210610/2100/20210610_210000.csv
# dim_name: marketplace, dim value: uk
# dim_name: platform, dim value: mobile_web
# t: time.struct_time(tm_year=2021, tm_mon=6, tm_mday=10, tm_hour=22, tm_min=0, tm_sec=0, tm_wday=3, tm_yday=161, tm_isdst=-1)
# File name: ./data/ecommerce/live/20210610/2200/20210610_220000.csv
# dim_name: marketplace, dim value: uk
# dim_name: platform, dim value: mobile_web
# t: time.struct_time(tm_year=2021, tm_mon=6, tm_mday=10, tm_hour=23, tm_min=0, tm_sec=0, tm_wday=3, tm_yday=161, tm_isdst=-1)
# File name: ./data/ecommerce/live/20210610/2300/20210610_230000.csv
# dim_name: marketplace, dim value: uk
# dim_name: platform, dim value: mobile_web
# ...
# t: time.struct_time(tm_year=2021, tm_mon=6, tm_mday=10, tm_hour=17, tm_min=0, tm_sec=0, tm_wday=3, tm_yday=161, tm_isdst=-1)
# File name: ./data/ecommerce/live/20210610/1700/20210610_170000.csv
# dim_name: marketplace, dim value: us
# dim_name: platform, dim value: mobile_app
# data: {'tseriesid': 'b385abcb02d24849b06c187b144311d2ec04f91f123066d2415c7b66d2364a7e36083c145d5ae9d39b6f3633316238c6ba0d14e851b9fd85cb429ae9433fd68e'}
# t: time.struct_time(tm_year=2021, tm_mon=6, tm_mday=10, tm_hour=17, tm_min=0, tm_sec=0, tm_wday=3, tm_yday=161, tm_isdst=-1)
# File name: ./data/ecommerce/live/20210610/1700/20210610_170000.csv
# dim_name: marketplace, dim value: it
# dim_name: platform, dim value: pc_web
# data: {'tseriesid': '2c54c039eea29141a2d3ae44c49ce9894a32c9d75280609cbe860aa4a7c134902958542b0fbaa4736a29ddeeba750d529a6f3daf7a4a87fd92644f34cc8dad1e'}
# t: time.struct_time(tm_year=2021, tm_mon=6, tm_mday=10, tm_hour=17, tm_min=0, tm_sec=0, tm_wday=3, tm_yday=161, tm_isdst=-1)
# File name: ./data/ecommerce/live/20210610/1700/20210610_170000.csv
# dim_name: marketplace, dim value: uk
# dim_name: platform, dim value: mobile_web
# data: {'tseriesid': '806ed8e77d183d791ea7e239568f7466fa0150f5c5e195f661db6fb2fb6d875ce9f21a3ff024830c6d4a6e5a0eea32211b772d217e5d708d59be320fcb1f6793'}
# t: time.struct_time(tm_year=2021, tm_mon=6, tm_mday=10, tm_hour=17, tm_min=0, tm_sec=0, tm_wday=3, tm_yday=161, tm_isdst=-1)
# File name: ./data/ecommerce/live/20210610/1700/20210610_170000.csv
# dim_name: marketplace, dim value: jp
# dim_name: platform, dim value: mobile_web
# data: {'tseriesid': '6e7d3fa0a0d67b75991ccce04c607a3a05fb3dc544d2f39281226977aab123a65fef6f1708b8f0eb0846c52fb41f7ed33c7b4240972a0900e5886889e9664d06'}
# t: time.struct_time(tm_year=2021, tm_mon=6, tm_mday=10, tm_hour=17, tm_min=0, tm_sec=0, tm_wday=3, tm_yday=161, tm_isdst=-1)
# File name: ./data/ecommerce/live/20210610/1700/20210610_170000.csv
# dim_name: marketplace, dim value: us
# dim_name: platform, dim value: mobile_web
# data: {'tseriesid': 'c7596342478b3356ae4a2abfb9178f33507d17c68ea7dafda7174fd0dd92e9c5487add54c57387f39f982d3070107a1274197348957c397047806841f9888020'}
# t: time.struct_time(tm_year=2021, tm_mon=6, tm_mday=10, tm_hour=17, tm_min=0, tm_sec=0, tm_wday=3, tm_yday=161, tm_isdst=-1)
# File name: ./data/ecommerce/live/20210610/1700/20210610_170000.csv
# dim_name: marketplace, dim value: fr
# dim_name: platform, dim value: pc_web
# data: {'tseriesid': 'a2ff4343a770c37f4784bec177e6fd202a86c2a5baf70dadc1af77f83ebcf8676fc157fc7dbe751eb521e5aafd52400af1f9a1145f17c81383c20fa0a45edd78'}
# t: time.struct_time(tm_year=2021, tm_mon=6, tm_mday=10, tm_hour=17, tm_min=0, tm_sec=0, tm_wday=3, tm_yday=161, tm_isdst=-1)
# File name: ./data/ecommerce/live/20210610/1700/20210610_170000.csv
# dim_name: marketplace, dim value: fr
# dim_name: platform, dim value: mobile_web
# data: {'tseriesid': 'ae6a56fa750ccb9aaf2e19e03c9bf443677eddab1146cdac2004109b2beb9a1fcccb2902871a9f3a9c87d1b166f710509f2feccfd4b36dbbb292a0345e353bd2'}
# t: time.struct_time(tm_year=2021, tm_mon=6, tm_mday=10, tm_hour=17, tm_min=0, tm_sec=0, tm_wday=3, tm_yday=161, tm_isdst=-1)
# File name: ./data/ecommerce/live/20210610/1700/20210610_170000.csv
# dim_name: marketplace, dim value: de
# dim_name: platform, dim value: pc_web
# data: {'tseriesid': '01982cf679fe2eb34d34b2bb81b9cc70ca5705f5357da7a47172cb5bc71f7cdc0c656ab6cb4d2e38bc96106490ae2d2351756b069b289eabab00f53cb0c2367f'}
# t: time.struct_time(tm_year=2021, tm_mon=6, tm_mday=10, tm_hour=17, tm_min=0, tm_sec=0, tm_wday=3, tm_yday=161, tm_isdst=-1)
# File name: ./data/ecommerce/live/20210610/1700/20210610_170000.csv
# dim_name: marketplace, dim value: de
# dim_name: platform, dim value: mobile_web
# data: {'tseriesid': '43f1075dfc573fcd6dd693aff946b2346128ef529901031a0307fe02e1e26f349344fef85aec8d5fdbf838c055436d8336bd751c501493d11c7772092eb2b14a'}
# t: time.struct_time(tm_year=2021, tm_mon=6, tm_mday=10, tm_hour=17, tm_min=0, tm_sec=0, tm_wday=3, tm_yday=161, tm_isdst=-1)
# File name: ./data/ecommerce/live/20210610/1700/20210610_170000.csv
# dim_name: marketplace, dim value: de
# dim_name: platform, dim value: mobile_app
# data: {'tseriesid': '2130951fd55518a5cd8878beb3644c4ee0ede00e0cfa54eca03bb45b17175374dcc2e1594e49880165e5b485e918a8e48af2eb88da4ed15c6f050fc866c4cd3b'}
# t: time.struct_time(tm_year=2021, tm_mon=6, tm_mday=10, tm_hour=17, tm_min=0, tm_sec=0, tm_wday=3, tm_yday=161, tm_isdst=-1)
# File name: ./data/ecommerce/live/20210610/1700/20210610_170000.csv
# dim_name: marketplace, dim value: us
# dim_name: platform, dim value: pc_web
# data: {'tseriesid': '148c383604889c167328d693738a53fb91239b0c93cdc547ded1c7ffcd3db5b3985d73cfaf4c4ce54a26f5f18ac0a4f62345d8a3a9349f92dc9461115ecbed18'}
# t: time.struct_time(tm_year=2021, tm_mon=6, tm_mday=10, tm_hour=17, tm_min=0, tm_sec=0, tm_wday=3, tm_yday=161, tm_isdst=-1)
# File name: ./data/ecommerce/live/20210610/1700/20210610_170000.csv
# dim_name: marketplace, dim value: fr
# dim_name: platform, dim value: mobile_app
# data: {'tseriesid': '1a1b734bd54546179395a8aaeaf896ecc7649eafbc3ed5172e68d01987cde1c09398cc1ac1fecf987b1a47c5cbcb249696bb212b2bbcd97f0b5f5397dc090ca3'}
# t: time.struct_time(tm_year=2021, tm_mon=6, tm_mday=10, tm_hour=17, tm_min=0, tm_sec=0, tm_wday=3, tm_yday=161, tm_isdst=-1)
# File name: ./data/ecommerce/live/20210610/1700/20210610_170000.csv
# dim_name: marketplace, dim value: de
# dim_name: platform, dim value: pc_web
# data: {'tseriesid': '946f9c83e27f1479186ef936b1f6c59428e3994af03bb80f9c8f62a8825482aba8fe49c7c223554e0a7c95b8b0f14e2ad2b42d5eac131ec4a834610bf4f4141d'}
# t: time.struct_time(tm_year=2021, tm_mon=6, tm_mday=10, tm_hour=17, tm_min=0, tm_sec=0, tm_wday=3, tm_yday=161, tm_isdst=-1)
# File name: ./data/ecommerce/live/20210610/1700/20210610_170000.csv
# dim_name: marketplace, dim value: de
# dim_name: platform, dim value: mobile_web
# data: {'tseriesid': '735f71013c2bca48516b835c02a4c3ab5ac972908c1f2327c1ce8ee3ddc71338be2ab2cd59a332af3267e436199529e25f24b3bc6e7d48cc99f1d48b72651318'}
# t: time.struct_time(tm_year=2021, tm_mon=6, tm_mday=10, tm_hour=17, tm_min=0, tm_sec=0, tm_wday=3, tm_yday=161, tm_isdst=-1)
# File name: ./data/ecommerce/live/20210610/1700/20210610_170000.csv
# dim_name: marketplace, dim value: jp
# dim_name: platform, dim value: mobile_web
# data: {'tseriesid': 'b385abcb02d24849b06c187b144311d2ec04f91f123066d2415c7b66d2364a7e36083c145d5ae9d39b6f3633316238c6ba0d14e851b9fd85cb429ae9433fd68e'}
# t: time.struct_time(tm_year=2021, tm_mon=6, tm_mday=10, tm_hour=17, tm_min=0, tm_sec=0, tm_wday=3, tm_yday=161, tm_isdst=-1)
# File name: ./data/ecommerce/live/20210610/1700/20210610_170000.csv
# dim_name: marketplace, dim value: it
# dim_name: platform, dim value: pc_web
# data: {'tseriesid': '230e2af30fbebf9485f6dad6dc67b196f655ce0a59998561c17bfa9e01abb614ea217e1c84b14081849caf40ac6dac42bd72cf6f4f460e335973225091950dfa'}
# t: time.struct_time(tm_year=2021, tm_mon=6, tm_mday=10, tm_hour=17, tm_min=0, tm_sec=0, tm_wday=3, tm_yday=161, tm_isdst=-1)
# File name: ./data/ecommerce/live/20210610/1700/20210610_170000.csv
# dim_name: marketplace, dim value: uk
# dim_name: platform, dim value: mobile_app
# data: {'tseriesid': 'ea7bf8b97c3d1d67938121800006cd4ffdd70a2f90a3d37c5121b4fabfdd0509d46e44941db21f2b69719d031148f3ec6b83d3574098c12a448dc594a58bc16c'}
# t: time.struct_time(tm_year=2021, tm_mon=6, tm_mday=10, tm_hour=17, tm_min=0, tm_sec=0, tm_wday=3, tm_yday=161, tm_isdst=-1)
# File name: ./data/ecommerce/live/20210610/1700/20210610_170000.csv
# dim_name: marketplace, dim value: uk
# dim_name: platform, dim value: pc_web
# data: {'tseriesid': '2a10775bb760f55e83943fea365cfa03bcac00047c9acf7b3197e91f01e22a1d8686fd7904ebf43db25b61ba638294c799d1c8cd7b4c11ef7f181936136d595c'}
# t: time.struct_time(tm_year=2021, tm_mon=6, tm_mday=10, tm_hour=17, tm_min=0, tm_sec=0, tm_wday=3, tm_yday=161, tm_isdst=-1)
# File name: ./data/ecommerce/live/20210610/1700/20210610_170000.csv
# dim_name: marketplace, dim value: us
# dim_name: platform, dim value: mobile_web
# data: {'tseriesid': 'd8ee40de893e6be62336ce71df8d9d018d85e0467712ab6d612f283192c8fa3a7b3901dbc631f8bb41a8fa4c5e6ff10caa47ea20fb958a5460474753f18e3b9c'}
# t: time.struct_time(tm_year=2021, tm_mon=6, tm_mday=10, tm_hour=17, tm_min=0, tm_sec=0, tm_wday=3, tm_yday=161, tm_isdst=-1)
# File name: ./data/ecommerce/live/20210610/1700/20210610_170000.csv
# dim_name: marketplace, dim value: us
# dim_name: platform, dim value: mobile_app
# data: {'tseriesid': '6ad0c55d7049b117aafee9be64e0b01bce13dbd0c25969c97470b14beef2d47345aad3bce9290bc3cfd6f8f2cb42e28129f8cf5d6cbe660de472c8988fc17af8'}
# t: time.struct_time(tm_year=2021, tm_mon=6, tm_mday=10, tm_hour=17, tm_min=0, tm_sec=0, tm_wday=3, tm_yday=161, tm_isdst=-1)
# File name: ./data/ecommerce/live/20210610/1700/20210610_170000.csv
# dim_name: marketplace, dim value: es
# dim_name: platform, dim value: mobile_app
# data: {'tseriesid': '5db96747f87730f37a6e23c9ba0b4995e478b29c967764fe204fb22244eb1b4db727062053d44b44bcf4297fb96c622d97d7b56d45c1585cf9d6946336f63fa9'}
# t: time.struct_time(tm_year=2021, tm_mon=6, tm_mday=10, tm_hour=17, tm_min=0, tm_sec=0, tm_wday=3, tm_yday=161, tm_isdst=-1)
# File name: ./data/ecommerce/live/20210610/1700/20210610_170000.csv
# dim_name: marketplace, dim value: us
# dim_name: platform, dim value: pc_web
# data: {'tseriesid': '1a1b734bd54546179395a8aaeaf896ecc7649eafbc3ed5172e68d01987cde1c09398cc1ac1fecf987b1a47c5cbcb249696bb212b2bbcd97f0b5f5397dc090ca3'}
# t: time.struct_time(tm_year=2021, tm_mon=6, tm_mday=10, tm_hour=17, tm_min=0, tm_sec=0, tm_wday=3, tm_yday=161, tm_isdst=-1)
# File name: ./data/ecommerce/live/20210610/1700/20210610_170000.csv
# dim_name: marketplace, dim value: de
# dim_name: platform, dim value: pc_web
# data: {'tseriesid': 'dbe384d71449cd7c8194b49fcc46df39921992c73d421ccf2f7dc1956a5e99dd591c23f03e542d5f54ea2334b9da640f77909e4a11683c34ed4008d6e9398812'}
# t: time.struct_time(tm_year=2021, tm_mon=6, tm_mday=10, tm_hour=17, tm_min=0, tm_sec=0, tm_wday=3, tm_yday=161, tm_isdst=-1)
# File name: ./data/ecommerce/live/20210610/1700/20210610_170000.csv
# dim_name: marketplace, dim value: it
# dim_name: platform, dim value: mobile_web
# data: {'tseriesid': 'b385abcb02d24849b06c187b144311d2ec04f91f123066d2415c7b66d2364a7e36083c145d5ae9d39b6f3633316238c6ba0d14e851b9fd85cb429ae9433fd68e'}
# t: time.struct_time(tm_year=2021, tm_mon=6, tm_mday=10, tm_hour=17, tm_min=0, tm_sec=0, tm_wday=3, tm_yday=161, tm_isdst=-1)
# File name: ./data/ecommerce/live/20210610/1700/20210610_170000.csv
# dim_name: marketplace, dim value: it
# dim_name: platform, dim value: pc_web
# data: {'tseriesid': '735f71013c2bca48516b835c02a4c3ab5ac972908c1f2327c1ce8ee3ddc71338be2ab2cd59a332af3267e436199529e25f24b3bc6e7d48cc99f1d48b72651318'}
# t: time.struct_time(tm_year=2021, tm_mon=6, tm_mday=10, tm_hour=17, tm_min=0, tm_sec=0, tm_wday=3, tm_yday=161, tm_isdst=-1)
# File name: ./data/ecommerce/live/20210610/1700/20210610_170000.csv
# dim_name: marketplace, dim value: jp
# dim_name: platform, dim value: mobile_web
# data: {'tseriesid': 'ea7bf8b97c3d1d67938121800006cd4ffdd70a2f90a3d37c5121b4fabfdd0509d46e44941db21f2b69719d031148f3ec6b83d3574098c12a448dc594a58bc16c'}
# t: time.struct_time(tm_year=2021, tm_mon=6, tm_mday=10, tm_hour=17, tm_min=0, tm_sec=0, tm_wday=3, tm_yday=161, tm_isdst=-1)
# File name: ./data/ecommerce/live/20210610/1700/20210610_170000.csv
# dim_name: marketplace, dim value: uk
# dim_name: platform, dim value: pc_web
# data: {'tseriesid': 'aa1caf7f795fd22b39a10e21a9b173df55d1a697c4d7c99a8ad901301bf903dda1ba20f2c412cdad0cdc47b7c57c1270ce323e75db53af03e8aed2d27d1281e2'}
# t: time.struct_time(tm_year=2021, tm_mon=6, tm_mday=10, tm_hour=17, tm_min=0, tm_sec=0, tm_wday=3, tm_yday=161, tm_isdst=-1)
# File name: ./data/ecommerce/live/20210610/1700/20210610_170000.csv
# dim_name: marketplace, dim value: es
# dim_name: platform, dim value: pc_web
# data: {'tseriesid': '2a10775bb760f55e83943fea365cfa03bcac00047c9acf7b3197e91f01e22a1d8686fd7904ebf43db25b61ba638294c799d1c8cd7b4c11ef7f181936136d595c'}
# t: time.struct_time(tm_year=2021, tm_mon=6, tm_mday=10, tm_hour=17, tm_min=0, tm_sec=0, tm_wday=3, tm_yday=161, tm_isdst=-1)
# File name: ./data/ecommerce/live/20210610/1700/20210610_170000.csv
# dim_name: marketplace, dim value: us
# dim_name: platform, dim value: mobile_web
# data: {'tseriesid': '5db96747f87730f37a6e23c9ba0b4995e478b29c967764fe204fb22244eb1b4db727062053d44b44bcf4297fb96c622d97d7b56d45c1585cf9d6946336f63fa9'}
# t: time.struct_time(tm_year=2021, tm_mon=6, tm_mday=10, tm_hour=17, tm_min=0, tm_sec=0, tm_wday=3, tm_yday=161, tm_isdst=-1)
# File name: ./data/ecommerce/live/20210610/1700/20210610_170000.csv
# dim_name: marketplace, dim value: us
# dim_name: platform, dim value: pc_web
# data: {'tseriesid': '230e2af30fbebf9485f6dad6dc67b196f655ce0a59998561c17bfa9e01abb614ea217e1c84b14081849caf40ac6dac42bd72cf6f4f460e335973225091950dfa'}
# t: time.struct_time(tm_year=2021, tm_mon=6, tm_mday=10, tm_hour=17, tm_min=0, tm_sec=0, tm_wday=3, tm_yday=161, tm_isdst=-1)
# File name: ./data/ecommerce/live/20210610/1700/20210610_170000.csv
# dim_name: marketplace, dim value: uk
# dim_name: platform, dim value: mobile_app
# data: {'tseriesid': 'd4496336e2fece5dfc237b82554ca809d7bc8092a52155606c68e4776ba2b8ac4903995c2efe6debe22479cee7a3f145364d0b2f49266c2fe48e802ee29e65da'}
# t: time.struct_time(tm_year=2021, tm_mon=6, tm_mday=10, tm_hour=17, tm_min=0, tm_sec=0, tm_wday=3, tm_yday=161, tm_isdst=-1)
# File name: ./data/ecommerce/live/20210610/1700/20210610_170000.csv
# dim_name: marketplace, dim value: jp
# dim_name: platform, dim value: pc_web
# Anomalies saved in dataframe.
#
# df_anomalies_by_ts:
#                timestamp    platform marketplace  views  revenue  \
# 0    2021-06-10 17:00:00  mobile_app          de    939   162.54
# 1    2021-06-10 17:00:00  mobile_app          es   1134   196.27
# 2    2021-06-10 17:00:00  mobile_app          fr   1264   218.76
# 3    2021-06-10 17:00:00  mobile_app          uk   1171   202.66
# 4    2021-06-10 17:00:00  mobile_app          us   1058   183.24
# ..                   ...         ...         ...    ...      ...
# 210  2021-06-11 23:00:00  mobile_web          de    763   132.13
# 211  2021-06-11 23:00:00  mobile_web          es    571    98.90
# 212  2021-06-11 23:00:00  mobile_web          jp    875   151.55
# 213  2021-06-11 23:00:00  mobile_web          uk   1182   204.71
# 214  2021-06-11 23:00:00      pc_web          de    775   134.17
#
#                                              tseriesid  \
# 0    43f1075dfc573fcd6dd693aff946b2346128ef52990103...
# 1    6ad0c55d7049b117aafee9be64e0b01bce13dbd0c25969...
# 2    148c383604889c167328d693738a53fb91239b0c93cdc5...
# 3    230e2af30fbebf9485f6dad6dc67b196f655ce0a599985...
# 4    d8ee40de893e6be62336ce71df8d9d018d85e0467712ab...
# ..                                                 ...
# 210  01982cf679fe2eb34d34b2bb81b9cc70ca5705f5357da7...
# 211  f2762c3d8bfd7a091b6c00fd13b8f75ee4a488038c84f1...
# 212  806ed8e77d183d791ea7e239568f7466fa0150f5c5e195...
# 213  2c54c039eea29141a2d3ae44c49ce9894a32c9d7528060...
# 214  ae6a56fa750ccb9aaf2e19e03c9bf443677eddab1146cd...
#
#                          anomaly_group_id anomaly_metric  anomaly_metric_value
# 0    8bcf8de1-6f82-4272-a822-5b1cc2a5b1a0          views                939.00
# 1    3febf42f-77a7-4bfe-afb1-24f256563495        revenue                196.27
# 2    3febf42f-77a7-4bfe-afb1-24f256563495        revenue                218.76
# 3    3febf42f-77a7-4bfe-afb1-24f256563495        revenue                202.66
# 4    8bcf8de1-6f82-4272-a822-5b1cc2a5b1a0          views               1058.00
# ..                                    ...            ...                   ...
# 210  5bbce1b9-a075-46cd-b060-f6c3dfe732c5          views                763.00
# 211  5bbce1b9-a075-46cd-b060-f6c3dfe732c5          views                571.00
# 212  5bbce1b9-a075-46cd-b060-f6c3dfe732c5          views                875.00
# 213  5bbce1b9-a075-46cd-b060-f6c3dfe732c5          views               1182.00
# 214  5bbce1b9-a075-46cd-b060-f6c3dfe732c5          views                775.00
#
# [215 rows x 9 columns]

# %%
pd.set_option('display.max_columns', None)
df_anomalies_by_ts.head()
# Out:
#              timestamp    platform marketplace  views  revenue  \
# 0  2021-06-10 17:00:00  mobile_app          de    939   162.54
# 1  2021-06-10 17:00:00  mobile_app          es   1134   196.27
# 2  2021-06-10 17:00:00  mobile_app          fr   1264   218.76
# 3  2021-06-10 17:00:00  mobile_app          uk   1171   202.66
# 4  2021-06-10 17:00:00  mobile_app          us   1058   183.24
#
#                                            tseriesid  \
# 0  43f1075dfc573fcd6dd693aff946b2346128ef52990103...
# 1  6ad0c55d7049b117aafee9be64e0b01bce13dbd0c25969...
# 2  148c383604889c167328d693738a53fb91239b0c93cdc5...
# 3  230e2af30fbebf9485f6dad6dc67b196f655ce0a599985...
# 4  d8ee40de893e6be62336ce71df8d9d018d85e0467712ab...
#
#                        anomaly_group_id anomaly_metric  anomaly_metric_value
# 0  8bcf8de1-6f82-4272-a822-5b1cc2a5b1a0          views                939.00
# 1  3febf42f-77a7-4bfe-afb1-24f256563495        revenue                196.27
# 2  3febf42f-77a7-4bfe-afb1-24f256563495        revenue                218.76
# 3  3febf42f-77a7-4bfe-afb1-24f256563495        revenue                202.66
# 4  8bcf8de1-6f82-4272-a822-5b1cc2a5b1a0          views               1058.00

# %% [markdown]
# ---
# ### 5.2. Export the Results
#
# Create a CSV file with anomaly results.

# %%
filename = ecom_anomaly_detector_arn.split(':')[-1] + "_anomalies.csv"
df_anomalies_by_ts.to_csv(filename, index=False )

# %% [markdown]
# ---
# ### 6.0. Create a private Workteam in SageMaker Console
#
# We do it through the AWS Console because it automatically integrates the workteam with Cognito for secure authentiation.
#
# Copy the the ARN of the workteam created through the console and enter it as response to the input command in the next cell.

# %%
workteam_ARN = 'arn:aws:sagemaker:us-west-2:095351214964:workteam/private-crowd/l4m-reviewers'

# %%
while workteam_ARN == '':
    workteam_ARN = input("Please enter the ARN of the Work Team:\n")
    if len(workteam_ARN) > 0:
        break

# WORKTEAM_ARN = arn:aws:sagemaker:us-west-2:095351214964:workteam/private-crowd/l4m-reviewers

# %%
# timestamp = time.strftime("%Y-%m-%d-%H-%M-%S", time.gmtime())

# Flow definition name - this value is unique per account and region. You can also provide your own value here.
l4m_flowDefinitionName = 'l4m-ecommerce-workflow'

# Task UI name - this value is unique per account and region. You can also provide your own value here.
l4m_taskUIName = 'l4m-ecommerce-ui'

# %% [markdown]
# ---
# ### 6.1. Create a human task UI
#
# Create a custom task template using HTML that will be presented to the workers. It uses Crowd HTML web components, a web standard that abstracts HTML markup, CSS, and JavaScript functionality into an HTML tag or set of tags.

# %%
# We customized the tabular template for our notebook as below
ecom_a2i_template = r"""
<script src="https://assets.crowd.aws/crowd-html-elements.js"></script>
<script src="https://cdnjs.cloudflare.com/ajax/libs/Chart.js/2.5.0/Chart.min.js"></script>

<crowd-form>

    <div>
        <h1>Ecommerce Revenue and Views by Platform and Market</h1>
    </div>

    <div style="margin-left: 40px">
        <h2>Instructions</h2>
        <p>The following entries were identified as anomalies.<br/> 
            Please review the views and revenue scores for the platform and market place.<br/>
            Check the radio button to confirm whether it was an anomaly.<br/>
            Please enter any optional comments for the anomaly.
        </p>
        <br>
    </div>
    <div>
    <table>
    <tr>
        <th></th>
        <th>Timestamp</th>
        <th>Platform</th>
        <th>Market Place</th>
        <th>Anomaly metric</th>
        <th>metric value</th>
        <th>Anomaly?</th>
        <th>Comment</th>
    </tr>
    
    {% for entry in task.input.l4m_ecom_anomaly %}

        <tr>
            <td><crowd-text-area name="sno-{{ forloop.index }}" value="{{ forloop.index }}"></crowd-text-area></td>
            <td><crowd-text-area name="timestamp-{{ forloop.index }}" value="{{ entry.timestamp }}"></crowd-text-area></td>
            <td><crowd-text-area name="platform-{{ forloop.index }}" value="{{ entry.platform }}"></crowd-text-area></td>
            <td><crowd-text-area name="marketplace-{{ forloop.index }}" value="{{ entry.marketplace }}"></crowd-text-area></td>     
            <td><crowd-text-area name="metric_name-{{ forloop.index }}" value="{{ entry.metric_name }}"></crowd-text-area></td>     
            <td><crowd-text-area name="metric_value-{{ forloop.index }}" value="{{ entry.metric_value }}"></crowd-text-area></td>     
            <td><crowd-checkbox name="anomaly_found-{{ forloop.index }}">Anomaly Found</crowd-checkbox></td>
            <td>
                <div><crowd-input name="comment-{{ forloop.index }}" placeholder="Enter optional comment"></crowd-input>
            </td>
        </tr>
      {% endfor %}
    </table>
    <br>
    </div>
</crowd-form>

<style>
  greenbg {
    background: #feee23;
    display: block;
  }

  table {
    border-spacing: 0; 
  }

  th {
    background-color: #8888ee;
    color: #f3f3f3;
    font-weight: 700;
  }

  th, td {
      border: 1px solid blue;
  }

  td {
    padding-left: 10px ;
    padding-right: 10px ;
  }

</style>

<script>
window.chartColors = {
  red: 'rgb(255, 99, 132)',
  orange: 'rgb(255, 159, 64)',
  yellow: 'rgb(255, 205, 86)',
  green: 'rgb(75, 192, 192)',
  blue: 'rgb(54, 162, 235)',
  purple: 'rgb(153, 102, 255)',
  grey: 'rgb(231,233,237)'
};

var signal = "{{task.input.l4m_ecom_anomaly | to_json}}";
var timestamp = [];
var platform = [];
var marketplace = [];
var metric_name = [];
var metric_value = [];

  
</script>
"""

sagemaker_client = boto3.client('sagemaker')

# Check if lookout for metrics UI for this example already exists
try:
    describe_human_task_ui_response = sagemaker_client.describe_human_task_ui(
        HumanTaskUiName=l4m_taskUIName
    )
    #print("\nDescribe human task UI: ")
    #pprint.pprint(describe_human_task_ui_response, width = 2)
    
except:
    print("Human task UI {} not found")
    describe_human_task_ui_response = {}

if not describe_human_task_ui_response:
    # Create the human task UI
    create_human_task_ui_response = sagemaker_client.create_human_task_ui(
        HumanTaskUiName=l4m_taskUIName,
        UiTemplate={'Content': ecom_a2i_template}) 

    print("\nCreate human task ui response: ")
    pprint.pprint(create_human_task_ui_response, width = 2)

    l4m_review_ui_arn = create_human_task_ui_response['HumanTaskUiArn']
else:
    l4m_review_ui_arn = describe_human_task_ui_response['HumanTaskUiArn']    
    
print("\nHuman task UI ARN: {}".format(l4m_review_ui_arn))
# Out:
# Human task UI {} not found
#
# Create human task ui response:
# {'HumanTaskUiArn': 'arn:aws:sagemaker:us-west-2:095351214964:human-task-ui/l4m-ecommerce-ui',
#  'ResponseMetadata': {'HTTPHeaders': {'content-length': '92',
#                                       'content-type': 'application/x-amz-json-1.1',
#                                       'date': 'Thu, '
#                                               '24 '
#                                               'Jun '
#                                               '2021 '
#                                               '03:14:28 '
#                                               'GMT',
#                                       'x-amzn-requestid': '40b7c218-f2ec-4fd2-8ea4-f42f18cc3caf'},
#                       'HTTPStatusCode': 200,
#                       'RequestId': '40b7c218-f2ec-4fd2-8ea4-f42f18cc3caf',
#                       'RetryAttempts': 0}}
#
# Human task UI ARN: arn:aws:sagemaker:us-west-2:095351214964:human-task-ui/l4m-ecommerce-ui

# %% [markdown]
# ---
# ### 6.2. Create a Human task Workflow
#
# We use Amazon Augmented AI's user interface to create a custom task workflow. The new flow is created only if one does not exist already with the same name. The results of human review are stored in an Amazon S3 bucket, which can be accessed by the client application.

# %%
sagemaker_role_arn = sagemaker.get_execution_role()

s3_output_path = f's3://' + bucket_name + '/ecommerce' + '/a2i-results'
print("S3 output path: {}".format(s3_output_path))

# Check if Amazon Lookout For Metrics Workflow exists
try:
    describe_flow_definition_response = sagemaker_client.describe_flow_definition(
        FlowDefinitionName=l4m_flowDefinitionName
    )
    ###### print describe_flow_definition_response
    #print("\nDescribe flow definition response: ")
    #pprint.pprint(describe_flow_definition_response, width=2)
    
except:
    describe_flow_definition_response = {}
    
# Create Amazon Lookout For Metrics Workflow if it does not exist already

if not describe_flow_definition_response:
    create_workflow_definition_response = sagemaker_client.create_flow_definition(
        FlowDefinitionName = l4m_flowDefinitionName,
        RoleArn=sagemaker_role_arn,
        HumanLoopConfig= {
            "WorkteamArn": workteam_ARN,
            "HumanTaskUiArn": l4m_review_ui_arn,
            "TaskCount": 1,
            "TaskDescription": "Review the anomalies detected by Amazon Lookout for Metrics",
            "TaskTitle": "Ecommerce Anomalies Review"
        },
        OutputConfig={
            "S3OutputPath" : s3_output_path
        }
    )
    
    # Wait until the newly created flow becomes Active
    while True:

        response = sagemaker_client.describe_flow_definition(FlowDefinitionName=l4m_flowDefinitionName)
        print(response['FlowDefinitionStatus'])
        if (response['FlowDefinitionStatus'] == 'Active'):
            print("Flow Definition is active")
            break
        time.sleep(5)


    flowDefinitionArn = create_workflow_definition_response['FlowDefinitionArn'] 

else:
    flowDefinitionArn = describe_flow_definition_response['FlowDefinitionArn'] 
        

print("Flow definition Arn: {}".format(flowDefinitionArn))
# Out:
# S3 output path: s3://095351214964-us-west-2-lookoutmetrics-lab/ecommerce/a2i-results
# Initializing
# Active
# Flow Definition is active
# Flow definition Arn: arn:aws:sagemaker:us-west-2:095351214964:flow-definition/l4m-ecommerce-workflow

# %%
# !aws s3 sync {data_dirname}/ecommerce/ s3://{bucket_name}/ecommerce/ --quiet

#!aws s3 cp ecommerce-continuous-detector_anomalies.csv s3://{bucket_name}/ecommerce/

# Anomaly records were saved in the dataframe in a previous cell. Otherwise read from csv file saved earlier.
if len(df_anomalies_by_ts) == 0:
    df_anomalies_by_ts = pd.read_csv("./ecommerce-continuous-detector_anomalies.csv")

df_anomalies_by_ts.head()
# Out:
#              timestamp    platform marketplace  views  revenue  \
# 0  2021-06-10 17:00:00  mobile_app          de    939   162.54
# 1  2021-06-10 17:00:00  mobile_app          es   1134   196.27
# 2  2021-06-10 17:00:00  mobile_app          fr   1264   218.76
# 3  2021-06-10 17:00:00  mobile_app          uk   1171   202.66
# 4  2021-06-10 17:00:00  mobile_app          us   1058   183.24
#
#                                            tseriesid  \
# 0  43f1075dfc573fcd6dd693aff946b2346128ef52990103...
# 1  6ad0c55d7049b117aafee9be64e0b01bce13dbd0c25969...
# 2  148c383604889c167328d693738a53fb91239b0c93cdc5...
# 3  230e2af30fbebf9485f6dad6dc67b196f655ce0a599985...
# 4  d8ee40de893e6be62336ce71df8d9d018d85e0467712ab...
#
#                        anomaly_group_id anomaly_metric  anomaly_metric_value
# 0  8bcf8de1-6f82-4272-a822-5b1cc2a5b1a0          views                939.00
# 1  3febf42f-77a7-4bfe-afb1-24f256563495        revenue                196.27
# 2  3febf42f-77a7-4bfe-afb1-24f256563495        revenue                218.76
# 3  3febf42f-77a7-4bfe-afb1-24f256563495        revenue                202.66
# 4  8bcf8de1-6f82-4272-a822-5b1cc2a5b1a0          views               1058.00

# %% [markdown]
# ---
# Create a Python list of anomalies to pass into the human review task

# %%
#tseriesid_list = ecom_anomalies_df['tseriesid'].astype(str).to_list()
timestamp_list = df_anomalies_by_ts['timestamp'].astype(str).to_list()
platform_list = df_anomalies_by_ts['platform'].astype(str).to_list()
marketplace_list = df_anomalies_by_ts['marketplace'].astype(str).to_list()

anomaly_metric_list = df_anomalies_by_ts['anomaly_metric'].astype(str).to_list()
metric_value_list = df_anomalies_by_ts['anomaly_metric_value'].astype(str).to_list()

for i in range(len(timestamp_list)):
     ecom_review_list = [ {'timestamp': timestamp_list[i], \
                            'platform': platform_list[i], \
                            'marketplace': marketplace_list[i], \
                            'metric_name': anomaly_metric_list[i], \
                            'metric_value': metric_value_list[i]} \
                            for i in range(len(timestamp_list))

                        ]
        
ip_content = {"l4m_ecom_anomaly": ecom_review_list} # passed into workflow

ecom_review_list
# Out:
# [{'timestamp': '2021-06-10 17:00:00',
#   'platform': 'mobile_app',
#   'marketplace': 'de',
#   'metric_name': 'views',
#   'metric_value': '939.0'},
#  {'timestamp': '2021-06-10 17:00:00',
#   'platform': 'mobile_app',
#   'marketplace': 'es',
#   'metric_name': 'revenue',
#   'metric_value': '196.27'},
#  {'timestamp': '2021-06-10 17:00:00',
#   'platform': 'mobile_app',
#   'marketplace': 'fr',
#   'metric_name': 'revenue',
#   'metric_value': '218.76'},
#  {'timestamp': '2021-06-10 17:00:00',
#   'platform': 'mobile_app',
#   'marketplace': 'uk',
#   'metric_name': 'revenue',
#   'metric_value': '202.66'},
#  {'timestamp': '2021-06-10 17:00:00',
#   'platform': 'mobile_app',
#   'marketplace': 'us',
#   'metric_name': 'views',
#   'metric_value': '1058.0'},
#  {'timestamp': '2021-06-10 17:00:00',
#   'platform': 'mobile_web',
#   'marketplace': 'de',
#   'metric_name': 'views',
#   'metric_value': '1171.0'},
#  {'timestamp': '2021-06-10 17:00:00',
#   'platform': 'mobile_web',
#   'marketplace': 'es',
#   'metric_name': 'views',
#   'metric_value': '982.0'},
#  {'timestamp': '2021-06-10 17:00:00',
#   'platform': 'mobile_web',
#   'marketplace': 'fr',
#   'metric_name': 'views',
#   'metric_value': '1168.0'},
#  {'timestamp': '2021-06-10 17:00:00',
#   'platform': 'mobile_web',
#   'marketplace': 'it',
#   'metric_name': 'revenue',
#   'metric_value': '151.04'},
#  {'timestamp': '2021-06-10 17:00:00',
#   'platform': 'mobile_web',
#   'marketplace': 'jp',
#   'metric_name': 'views',
#   'metric_value': '1020.0'},
#  {'timestamp': '2021-06-10 17:00:00',
#   'platform': 'mobile_web',
#   'marketplace': 'uk',
#   'metric_name': 'views',
#   'metric_value': '1044.0'},
#  {'timestamp': '2021-06-10 17:00:00',
#   'platform': 'mobile_web',
#   'marketplace': 'us',
#   'metric_name': 'views',
#   'metric_value': '1137.0'},
#  {'timestamp': '2021-06-10 17:00:00',
#   'platform': 'pc_web',
#   'marketplace': 'de',
#   'metric_name': 'views',
#   'metric_value': '1208.0'},
#  {'timestamp': '2021-06-10 17:00:00',
#   'platform': 'pc_web',
#   'marketplace': 'es',
#   'metric_name': 'revenue',
#   'metric_value': '198.83'},
#  {'timestamp': '2021-06-10 17:00:00',
#   'platform': 'pc_web',
#   'marketplace': 'fr',
#   'metric_name': 'views',
#   'metric_value': '1004.0'},
#  {'timestamp': '2021-06-10 17:00:00',
#   'platform': 'pc_web',
#   'marketplace': 'it',
#   'metric_name': 'views',
#   'metric_value': '804.0'},
#  {'timestamp': '2021-06-10 17:00:00',
#   'platform': 'pc_web',
#   'marketplace': 'jp',
#   'metric_name': 'revenue',
#   'metric_value': '209.82'},
#  {'timestamp': '2021-06-10 17:00:00',
#   'platform': 'pc_web',
#   'marketplace': 'uk',
#   'metric_name': 'revenue',
#   'metric_value': '154.36'},
#  {'timestamp': '2021-06-10 17:00:00',
#   'platform': 'pc_web',
#   'marketplace': 'us',
#   'metric_name': 'views',
#   'metric_value': '1116.0'},
#  {'timestamp': '2021-06-10 18:00:00',
#   'platform': 'mobile_app',
#   'marketplace': 'de',
#   'metric_name': 'views',
#   'metric_value': '1030.0'},
#  {'timestamp': '2021-06-10 18:00:00',
#   'platform': 'mobile_app',
#   'marketplace': 'es',
#   'metric_name': 'revenue',
#   'metric_value': '189.63'},
#  {'timestamp': '2021-06-10 18:00:00',
#   'platform': 'mobile_app',
#   'marketplace': 'fr',
#   'metric_name': 'revenue',
#   'metric_value': '200.36'},
#  {'timestamp': '2021-06-10 18:00:00',
#   'platform': 'mobile_app',
#   'marketplace': 'uk',
#   'metric_name': 'revenue',
#   'metric_value': '193.46'},
#  {'timestamp': '2021-06-10 18:00:00',
#   'platform': 'mobile_app',
#   'marketplace': 'us',
#   'metric_name': 'views',
#   'metric_value': '937.0'},
#  {'timestamp': '2021-06-10 18:00:00',
#   'platform': 'mobile_web',
#   'marketplace': 'de',
#   'metric_name': 'views',
#   'metric_value': '1175.0'},
#  {'timestamp': '2021-06-10 18:00:00',
#   'platform': 'mobile_web',
#   'marketplace': 'es',
#   'metric_name': 'views',
#   'metric_value': '980.0'},
#  {'timestamp': '2021-06-10 18:00:00',
#   'platform': 'mobile_web',
#   'marketplace': 'fr',
#   'metric_name': 'views',
#   'metric_value': '1174.0'},
#  {'timestamp': '2021-06-10 18:00:00',
#   'platform': 'mobile_web',
#   'marketplace': 'jp',
#   'metric_name': 'views',
#   'metric_value': '1073.0'},
#  {'timestamp': '2021-06-10 18:00:00',
#   'platform': 'mobile_web',
#   'marketplace': 'uk',
#   'metric_name': 'views',
#   'metric_value': '1141.0'},
#  {'timestamp': '2021-06-10 18:00:00',
#   'platform': 'mobile_web',
#   'marketplace': 'us',
#   'metric_name': 'views',
#   'metric_value': '1228.0'},
#  {'timestamp': '2021-06-10 18:00:00',
#   'platform': 'pc_web',
#   'marketplace': 'de',
#   'metric_name': 'views',
#   'metric_value': '1187.0'},
#  {'timestamp': '2021-06-10 18:00:00',
#   'platform': 'pc_web',
#   'marketplace': 'fr',
#   'metric_name': 'views',
#   'metric_value': '1073.0'},
#  {'timestamp': '2021-06-10 18:00:00',
#   'platform': 'pc_web',
#   'marketplace': 'it',
#   'metric_name': 'views',
#   'metric_value': '866.0'},
#  {'timestamp': '2021-06-10 18:00:00',
#   'platform': 'pc_web',
#   'marketplace': 'uk',
#   'metric_name': 'revenue',
#   'metric_value': '144.14'},
#  {'timestamp': '2021-06-10 18:00:00',
#   'platform': 'pc_web',
#   'marketplace': 'us',
#   'metric_name': 'views',
#   'metric_value': '1109.0'},
#  {'timestamp': '2021-06-10 19:00:00',
#   'platform': 'mobile_app',
#   'marketplace': 'de',
#   'metric_name': 'views',
#   'metric_value': '1112.0'},
#  {'timestamp': '2021-06-10 19:00:00',
#   'platform': 'mobile_app',
#   'marketplace': 'us',
#   'metric_name': 'views',
#   'metric_value': '822.0'},
#  {'timestamp': '2021-06-10 19:00:00',
#   'platform': 'mobile_web',
#   'marketplace': 'de',
#   'metric_name': 'views',
#   'metric_value': '1146.0'},
#  {'timestamp': '2021-06-10 19:00:00',
#   'platform': 'mobile_web',
#   'marketplace': 'es',
#   'metric_name': 'views',
#   'metric_value': '912.0'},
#  {'timestamp': '2021-06-10 19:00:00',
#   'platform': 'mobile_web',
#   'marketplace': 'fr',
#   'metric_name': 'views',
#   'metric_value': '1138.0'},
#  {'timestamp': '2021-06-10 19:00:00',
#   'platform': 'mobile_web',
#   'marketplace': 'jp',
#   'metric_name': 'views',
#   'metric_value': '1094.0'},
#  {'timestamp': '2021-06-10 19:00:00',
#   'platform': 'mobile_web',
#   'marketplace': 'uk',
#   'metric_name': 'views',
#   'metric_value': '1222.0'},
#  {'timestamp': '2021-06-10 19:00:00',
#   'platform': 'mobile_web',
#   'marketplace': 'us',
#   'metric_name': 'views',
#   'metric_value': '1265.0'},
#  {'timestamp': '2021-06-10 19:00:00',
#   'platform': 'pc_web',
#   'marketplace': 'de',
#   'metric_name': 'views',
#   'metric_value': '1153.0'},
#  {'timestamp': '2021-06-10 19:00:00',
#   'platform': 'pc_web',
#   'marketplace': 'fr',
#   'metric_name': 'views',
#   'metric_value': '1112.0'},
#  {'timestamp': '2021-06-10 19:00:00',
#   'platform': 'pc_web',
#   'marketplace': 'it',
#   'metric_name': 'views',
#   'metric_value': '905.0'},
#  {'timestamp': '2021-06-10 19:00:00',
#   'platform': 'pc_web',
#   'marketplace': 'us',
#   'metric_name': 'views',
#   'metric_value': '1076.0'},
#  {'timestamp': '2021-06-10 20:00:00',
#   'platform': 'mobile_app',
#   'marketplace': 'de',
#   'metric_name': 'views',
#   'metric_value': '1151.0'},
#  {'timestamp': '2021-06-10 20:00:00',
#   'platform': 'mobile_app',
#   'marketplace': 'us',
#   'metric_name': 'views',
#   'metric_value': '686.0'},
#  {'timestamp': '2021-06-10 20:00:00',
#   'platform': 'mobile_web',
#   'marketplace': 'de',
#   'metric_name': 'views',
#   'metric_value': '1073.0'},
#  {'timestamp': '2021-06-10 20:00:00',
#   'platform': 'mobile_web',
#   'marketplace': 'es',
#   'metric_name': 'views',
#   'metric_value': '858.0'},
#  {'timestamp': '2021-06-10 20:00:00',
#   'platform': 'mobile_web',
#   'marketplace': 'fr',
#   'metric_name': 'views',
#   'metric_value': '1089.0'},
#  {'timestamp': '2021-06-10 20:00:00',
#   'platform': 'mobile_web',
#   'marketplace': 'jp',
#   'metric_name': 'views',
#   'metric_value': '1089.0'},
#  {'timestamp': '2021-06-10 20:00:00',
#   'platform': 'mobile_web',
#   'marketplace': 'uk',
#   'metric_name': 'views',
#   'metric_value': '1255.0'},
#  {'timestamp': '2021-06-10 20:00:00',
#   'platform': 'mobile_web',
#   'marketplace': 'us',
#   'metric_name': 'views',
#   'metric_value': '1304.0'},
#  {'timestamp': '2021-06-10 20:00:00',
#   'platform': 'pc_web',
#   'marketplace': 'de',
#   'metric_name': 'views',
#   'metric_value': '1106.0'},
#  {'timestamp': '2021-06-10 20:00:00',
#   'platform': 'pc_web',
#   'marketplace': 'fr',
#   'metric_name': 'views',
#   'metric_value': '1120.0'},
#  {'timestamp': '2021-06-10 20:00:00',
#   'platform': 'pc_web',
#   'marketplace': 'it',
#   'metric_name': 'views',
#   'metric_value': '921.0'},
#  {'timestamp': '2021-06-10 20:00:00',
#   'platform': 'pc_web',
#   'marketplace': 'us',
#   'metric_name': 'views',
#   'metric_value': '1008.0'},
#  {'timestamp': '2021-06-10 21:00:00',
#   'platform': 'mobile_app',
#   'marketplace': 'de',
#   'metric_name': 'views',
#   'metric_value': '1159.0'},
#  {'timestamp': '2021-06-10 21:00:00',
#   'platform': 'mobile_app',
#   'marketplace': 'fr',
#   'metric_name': 'revenue',
#   'metric_value': '275.24'},
#  {'timestamp': '2021-06-10 21:00:00',
#   'platform': 'mobile_app',
#   'marketplace': 'us',
#   'metric_name': 'views',
#   'metric_value': '539.0'},
#  {'timestamp': '2021-06-10 21:00:00',
#   'platform': 'mobile_web',
#   'marketplace': 'de',
#   'metric_name': 'views',
#   'metric_value': '993.0'},
#  {'timestamp': '2021-06-10 21:00:00',
#   'platform': 'mobile_web',
#   'marketplace': 'es',
#   'metric_name': 'views',
#   'metric_value': '778.0'},
#  {'timestamp': '2021-06-10 21:00:00',
#   'platform': 'mobile_web',
#   'marketplace': 'fr',
#   'metric_name': 'views',
#   'metric_value': '982.0'},
#  {'timestamp': '2021-06-10 21:00:00',
#   'platform': 'mobile_web',
#   'marketplace': 'jp',
#   'metric_name': 'views',
#   'metric_value': '1044.0'},
#  {'timestamp': '2021-06-10 21:00:00',
#   'platform': 'mobile_web',
#   'marketplace': 'uk',
#   'metric_name': 'views',
#   'metric_value': '1267.0'},
#  {'timestamp': '2021-06-10 21:00:00',
#   'platform': 'mobile_web',
#   'marketplace': 'us',
#   'metric_name': 'views',
#   'metric_value': '1283.0'},
#  {'timestamp': '2021-06-10 21:00:00',
#   'platform': 'pc_web',
#   'marketplace': 'de',
#   'metric_name': 'views',
#   'metric_value': '1005.0'},
#  {'timestamp': '2021-06-10 21:00:00',
#   'platform': 'pc_web',
#   'marketplace': 'fr',
#   'metric_name': 'views',
#   'metric_value': '1097.0'},
#  {'timestamp': '2021-06-10 21:00:00',
#   'platform': 'pc_web',
#   'marketplace': 'it',
#   'metric_name': 'views',
#   'metric_value': '924.0'},
#  {'timestamp': '2021-06-10 21:00:00',
#   'platform': 'pc_web',
#   'marketplace': 'us',
#   'metric_name': 'views',
#   'metric_value': '915.0'},
#  {'timestamp': '2021-06-10 22:00:00',
#   'platform': 'mobile_app',
#   'marketplace': 'de',
#   'metric_name': 'views',
#   'metric_value': '1140.0'},
#  {'timestamp': '2021-06-10 22:00:00',
#   'platform': 'mobile_app',
#   'marketplace': 'us',
#   'metric_name': 'views',
#   'metric_value': '425.0'},
#  {'timestamp': '2021-06-10 22:00:00',
#   'platform': 'mobile_web',
#   'marketplace': 'de',
#   'metric_name': 'views',
#   'metric_value': '892.0'},
#  {'timestamp': '2021-06-10 22:00:00',
#   'platform': 'mobile_web',
#   'marketplace': 'es',
#   'metric_name': 'views',
#   'metric_value': '688.0'},
#  {'timestamp': '2021-06-10 22:00:00',
#   'platform': 'mobile_web',
#   'marketplace': 'fr',
#   'metric_name': 'views',
#   'metric_value': '889.0'},
#  {'timestamp': '2021-06-10 22:00:00',
#   'platform': 'mobile_web',
#   'marketplace': 'jp',
#   'metric_name': 'views',
#   'metric_value': '979.0'},
#  {'timestamp': '2021-06-10 22:00:00',
#   'platform': 'mobile_web',
#   'marketplace': 'uk',
#   'metric_name': 'views',
#   'metric_value': '1240.0'},
#  {'timestamp': '2021-06-10 22:00:00',
#   'platform': 'mobile_web',
#   'marketplace': 'us',
#   'metric_name': 'views',
#   'metric_value': '1218.0'},
#  {'timestamp': '2021-06-10 22:00:00',
#   'platform': 'pc_web',
#   'marketplace': 'de',
#   'metric_name': 'views',
#   'metric_value': '890.0'},
#  {'timestamp': '2021-06-10 22:00:00',
#   'platform': 'pc_web',
#   'marketplace': 'fr',
#   'metric_name': 'views',
#   'metric_value': '1038.0'},
#  {'timestamp': '2021-06-10 22:00:00',
#   'platform': 'pc_web',
#   'marketplace': 'it',
#   'metric_name': 'views',
#   'metric_value': '884.0'},
#  {'timestamp': '2021-06-10 22:00:00',
#   'platform': 'pc_web',
#   'marketplace': 'us',
#   'metric_name': 'views',
#   'metric_value': '800.0'},
#  {'timestamp': '2021-06-10 23:00:00',
#   'platform': 'mobile_app',
#   'marketplace': 'de',
#   'metric_name': 'views',
#   'metric_value': '1097.0'},
#  {'timestamp': '2021-06-10 23:00:00',
#   'platform': 'mobile_app',
#   'marketplace': 'us',
#   'metric_name': 'views',
#   'metric_value': '320.0'},
#  {'timestamp': '2021-06-10 23:00:00',
#   'platform': 'mobile_web',
#   'marketplace': 'de',
#   'metric_name': 'views',
#   'metric_value': '773.0'},
#  {'timestamp': '2021-06-10 23:00:00',
#   'platform': 'mobile_web',
#   'marketplace': 'es',
#   'metric_name': 'views',
#   'metric_value': '592.0'},
#  {'timestamp': '2021-06-10 23:00:00',
#   'platform': 'mobile_web',
#   'marketplace': 'fr',
#   'metric_name': 'views',
#   'metric_value': '767.0'},
#  {'timestamp': '2021-06-10 23:00:00',
#   'platform': 'mobile_web',
#   'marketplace': 'jp',
#   'metric_name': 'views',
#   'metric_value': '880.0'},
#  {'timestamp': '2021-06-10 23:00:00',
#   'platform': 'mobile_web',
#   'marketplace': 'uk',
#   'metric_name': 'views',
#   'metric_value': '1188.0'},
#  {'timestamp': '2021-06-10 23:00:00',
#   'platform': 'mobile_web',
#   'marketplace': 'us',
#   'metric_name': 'views',
#   'metric_value': '1115.0'},
#  {'timestamp': '2021-06-10 23:00:00',
#   'platform': 'pc_web',
#   'marketplace': 'de',
#   'metric_name': 'views',
#   'metric_value': '787.0'},
#  {'timestamp': '2021-06-10 23:00:00',
#   'platform': 'pc_web',
#   'marketplace': 'fr',
#   'metric_name': 'views',
#   'metric_value': '959.0'},
#  {'timestamp': '2021-06-10 23:00:00',
#   'platform': 'pc_web',
#   'marketplace': 'it',
#   'metric_name': 'views',
#   'metric_value': '832.0'},
#  {'timestamp': '2021-06-10 23:00:00',
#   'platform': 'pc_web',
#   'marketplace': 'us',
#   'metric_name': 'views',
#   'metric_value': '686.0'},
#  {'timestamp': '2021-06-11 00:00:00',
#   'platform': 'mobile_app',
#   'marketplace': 'de',
#   'metric_name': 'views',
#   'metric_value': '1010.0'},
#  {'timestamp': '2021-06-11 00:00:00',
#   'platform': 'mobile_app',
#   'marketplace': 'us',
#   'metric_name': 'views',
#   'metric_value': '221.0'},
#  {'timestamp': '2021-06-11 00:00:00',
#   'platform': 'mobile_web',
#   'marketplace': 'de',
#   'metric_name': 'views',
#   'metric_value': '642.0'},
#  {'timestamp': '2021-06-11 00:00:00',
#   'platform': 'mobile_web',
#   'marketplace': 'es',
#   'metric_name': 'views',
#   'metric_value': '468.0'},
#  {'timestamp': '2021-06-11 00:00:00',
#   'platform': 'mobile_web',
#   'marketplace': 'fr',
#   'metric_name': 'views',
#   'metric_value': '643.0'},
#  {'timestamp': '2021-06-11 00:00:00',
#   'platform': 'mobile_web',
#   'marketplace': 'jp',
#   'metric_name': 'views',
#   'metric_value': '770.0'},
#  {'timestamp': '2021-06-11 00:00:00',
#   'platform': 'mobile_web',
#   'marketplace': 'uk',
#   'metric_name': 'views',
#   'metric_value': '1107.0'},
#  {'timestamp': '2021-06-11 00:00:00',
#   'platform': 'mobile_web',
#   'marketplace': 'us',
#   'metric_name': 'views',
#   'metric_value': '1001.0'},
#  {'timestamp': '2021-06-11 00:00:00',
#   'platform': 'pc_web',
#   'marketplace': 'de',
#   'metric_name': 'views',
#   'metric_value': '657.0'},
#  {'timestamp': '2021-06-11 00:00:00',
#   'platform': 'pc_web',
#   'marketplace': 'fr',
#   'metric_name': 'views',
#   'metric_value': '858.0'},
#  {'timestamp': '2021-06-11 00:00:00',
#   'platform': 'pc_web',
#   'marketplace': 'it',
#   'metric_name': 'views',
#   'metric_value': '757.0'},
#  {'timestamp': '2021-06-11 00:00:00',
#   'platform': 'pc_web',
#   'marketplace': 'us',
#   'metric_name': 'views',
#   'metric_value': '575.0'},
#  {'timestamp': '2021-06-11 01:00:00',
#   'platform': 'mobile_app',
#   'marketplace': 'de',
#   'metric_name': 'views',
#   'metric_value': '915.0'},
#  {'timestamp': '2021-06-11 01:00:00',
#   'platform': 'mobile_app',
#   'marketplace': 'us',
#   'metric_name': 'views',
#   'metric_value': '184.0'},
#  {'timestamp': '2021-06-11 01:00:00',
#   'platform': 'mobile_web',
#   'marketplace': 'de',
#   'metric_name': 'views',
#   'metric_value': '528.0'},
#  {'timestamp': '2021-06-11 01:00:00',
#   'platform': 'mobile_web',
#   'marketplace': 'es',
#   'metric_name': 'views',
#   'metric_value': '407.0'},
#  {'timestamp': '2021-06-11 01:00:00',
#   'platform': 'mobile_web',
#   'marketplace': 'fr',
#   'metric_name': 'views',
#   'metric_value': '533.0'},
#  {'timestamp': '2021-06-11 01:00:00',
#   'platform': 'mobile_web',
#   'marketplace': 'jp',
#   'metric_name': 'views',
#   'metric_value': '646.0'},
#  {'timestamp': '2021-06-11 01:00:00',
#   'platform': 'mobile_web',
#   'marketplace': 'uk',
#   'metric_name': 'views',
#   'metric_value': '996.0'},
#  {'timestamp': '2021-06-11 01:00:00',
#   'platform': 'mobile_web',
#   'marketplace': 'us',
#   'metric_name': 'views',
#   'metric_value': '868.0'},
#  {'timestamp': '2021-06-11 01:00:00',
#   'platform': 'pc_web',
#   'marketplace': 'de',
#   'metric_name': 'views',
#   'metric_value': '536.0'},
#  {'timestamp': '2021-06-11 01:00:00',
#   'platform': 'pc_web',
#   'marketplace': 'fr',
#   'metric_name': 'views',
#   'metric_value': '729.0'},
#  {'timestamp': '2021-06-11 01:00:00',
#   'platform': 'pc_web',
#   'marketplace': 'it',
#   'metric_name': 'views',
#   'metric_value': '669.0'},
#  {'timestamp': '2021-06-11 01:00:00',
#   'platform': 'pc_web',
#   'marketplace': 'us',
#   'metric_name': 'views',
#   'metric_value': '0.0'},
#  {'timestamp': '2021-06-11 02:00:00',
#   'platform': 'mobile_app',
#   'marketplace': 'de',
#   'metric_name': 'views',
#   'metric_value': '804.0'},
#  {'timestamp': '2021-06-11 02:00:00',
#   'platform': 'mobile_app',
#   'marketplace': 'us',
#   'metric_name': 'views',
#   'metric_value': '158.0'},
#  {'timestamp': '2021-06-11 02:00:00',
#   'platform': 'mobile_web',
#   'marketplace': 'de',
#   'metric_name': 'views',
#   'metric_value': '426.0'},
#  {'timestamp': '2021-06-11 02:00:00',
#   'platform': 'mobile_web',
#   'marketplace': 'es',
#   'metric_name': 'views',
#   'metric_value': '308.0'},
#  {'timestamp': '2021-06-11 02:00:00',
#   'platform': 'mobile_web',
#   'marketplace': 'fr',
#   'metric_name': 'views',
#   'metric_value': '440.0'},
#  {'timestamp': '2021-06-11 02:00:00',
#   'platform': 'mobile_web',
#   'marketplace': 'jp',
#   'metric_name': 'views',
#   'metric_value': '519.0'},
#  {'timestamp': '2021-06-11 02:00:00',
#   'platform': 'mobile_web',
#   'marketplace': 'uk',
#   'metric_name': 'views',
#   'metric_value': '878.0'},
#  {'timestamp': '2021-06-11 02:00:00',
#   'platform': 'mobile_web',
#   'marketplace': 'us',
#   'metric_name': 'views',
#   'metric_value': '729.0'},
#  {'timestamp': '2021-06-11 02:00:00',
#   'platform': 'pc_web',
#   'marketplace': 'de',
#   'metric_name': 'views',
#   'metric_value': '425.0'},
#  {'timestamp': '2021-06-11 02:00:00',
#   'platform': 'pc_web',
#   'marketplace': 'fr',
#   'metric_name': 'views',
#   'metric_value': '615.0'},
#  {'timestamp': '2021-06-11 02:00:00',
#   'platform': 'pc_web',
#   'marketplace': 'it',
#   'metric_name': 'views',
#   'metric_value': '571.0'},
#  {'timestamp': '2021-06-11 02:00:00',
#   'platform': 'pc_web',
#   'marketplace': 'us',
#   'metric_name': 'views',
#   'metric_value': '0.0'},
#  {'timestamp': '2021-06-11 09:00:00',
#   'platform': 'mobile_web',
#   'marketplace': 'de',
#   'metric_name': 'views',
#   'metric_value': '425.0'},
#  {'timestamp': '2021-06-11 09:00:00',
#   'platform': 'mobile_web',
#   'marketplace': 'es',
#   'metric_name': 'views',
#   'metric_value': '450.0'},
#  {'timestamp': '2021-06-11 09:00:00',
#   'platform': 'mobile_web',
#   'marketplace': 'jp',
#   'metric_name': 'views',
#   'metric_value': '203.0'},
#  {'timestamp': '2021-06-11 09:00:00',
#   'platform': 'mobile_web',
#   'marketplace': 'uk',
#   'metric_name': 'views',
#   'metric_value': '273.0'},
#  {'timestamp': '2021-06-11 09:00:00',
#   'platform': 'pc_web',
#   'marketplace': 'de',
#   'metric_name': 'views',
#   'metric_value': '434.0'},
#  {'timestamp': '2021-06-11 10:00:00',
#   'platform': 'mobile_app',
#   'marketplace': 'us',
#   'metric_name': 'revenue',
#   'metric_value': '241.76'},
#  {'timestamp': '2021-06-11 10:00:00',
#   'platform': 'mobile_web',
#   'marketplace': 'de',
#   'metric_name': 'views',
#   'metric_value': '519.0'},
#  {'timestamp': '2021-06-11 10:00:00',
#   'platform': 'mobile_web',
#   'marketplace': 'es',
#   'metric_name': 'views',
#   'metric_value': '550.0'},
#  {'timestamp': '2021-06-11 10:00:00',
#   'platform': 'mobile_web',
#   'marketplace': 'jp',
#   'metric_name': 'views',
#   'metric_value': '267.0'},
#  {'timestamp': '2021-06-11 10:00:00',
#   'platform': 'mobile_web',
#   'marketplace': 'uk',
#   'metric_name': 'views',
#   'metric_value': '305.0'},
#  {'timestamp': '2021-06-11 10:00:00',
#   'platform': 'pc_web',
#   'marketplace': 'de',
#   'metric_name': 'views',
#   'metric_value': '528.0'},
#  {'timestamp': '2021-06-11 10:00:00',
#   'platform': 'pc_web',
#   'marketplace': 'it',
#   'metric_name': 'revenue',
#   'metric_value': '37.82'},
#  {'timestamp': '2021-06-11 11:00:00',
#   'platform': 'mobile_app',
#   'marketplace': 'us',
#   'metric_name': 'revenue',
#   'metric_value': '259.14'},
#  {'timestamp': '2021-06-11 11:00:00',
#   'platform': 'mobile_web',
#   'marketplace': 'de',
#   'metric_name': 'views',
#   'metric_value': '645.0'},
#  {'timestamp': '2021-06-11 11:00:00',
#   'platform': 'mobile_web',
#   'marketplace': 'es',
#   'metric_name': 'views',
#   'metric_value': '633.0'},
#  {'timestamp': '2021-06-11 11:00:00',
#   'platform': 'mobile_web',
#   'marketplace': 'jp',
#   'metric_name': 'views',
#   'metric_value': '369.0'},
#  {'timestamp': '2021-06-11 11:00:00',
#   'platform': 'mobile_web',
#   'marketplace': 'uk',
#   'metric_name': 'views',
#   'metric_value': '354.0'},
#  {'timestamp': '2021-06-11 11:00:00',
#   'platform': 'pc_web',
#   'marketplace': 'de',
#   'metric_name': 'views',
#   'metric_value': '661.0'},
#  {'timestamp': '2021-06-11 11:00:00',
#   'platform': 'pc_web',
#   'marketplace': 'it',
#   'metric_name': 'revenue',
#   'metric_value': '46.26'},
#  {'timestamp': '2021-06-11 12:00:00',
#   'platform': 'mobile_app',
#   'marketplace': 'us',
#   'metric_name': 'revenue',
#   'metric_value': '272.43'},
#  {'timestamp': '2021-06-11 12:00:00',
#   'platform': 'mobile_web',
#   'marketplace': 'de',
#   'metric_name': 'views',
#   'metric_value': '770.0'},
#  {'timestamp': '2021-06-11 12:00:00',
#   'platform': 'mobile_web',
#   'marketplace': 'es',
#   'metric_name': 'views',
#   'metric_value': '728.0'},
#  {'timestamp': '2021-06-11 12:00:00',
#   'platform': 'mobile_web',
#   'marketplace': 'jp',
#   'metric_name': 'views',
#   'metric_value': '478.0'},
#  {'timestamp': '2021-06-11 12:00:00',
#   'platform': 'mobile_web',
#   'marketplace': 'uk',
#   'metric_name': 'views',
#   'metric_value': '450.0'},
#  {'timestamp': '2021-06-11 12:00:00',
#   'platform': 'pc_web',
#   'marketplace': 'de',
#   'metric_name': 'views',
#   'metric_value': '775.0'},
#  {'timestamp': '2021-06-11 12:00:00',
#   'platform': 'pc_web',
#   'marketplace': 'it',
#   'metric_name': 'revenue',
#   'metric_value': '59.29'},
#  {'timestamp': '2021-06-11 13:00:00',
#   'platform': 'mobile_app',
#   'marketplace': 'us',
#   'metric_name': 'revenue',
#   'metric_value': '282.14'},
#  {'timestamp': '2021-06-11 13:00:00',
#   'platform': 'mobile_web',
#   'marketplace': 'de',
#   'metric_name': 'views',
#   'metric_value': '889.0'},
#  {'timestamp': '2021-06-11 13:00:00',
#   'platform': 'mobile_web',
#   'marketplace': 'es',
#   'metric_name': 'views',
#   'metric_value': '818.0'},
#  {'timestamp': '2021-06-11 13:00:00',
#   'platform': 'mobile_web',
#   'marketplace': 'jp',
#   'metric_name': 'views',
#   'metric_value': '604.0'},
#  {'timestamp': '2021-06-11 13:00:00',
#   'platform': 'mobile_web',
#   'marketplace': 'uk',
#   'metric_name': 'views',
#   'metric_value': '549.0'},
#  {'timestamp': '2021-06-11 13:00:00',
#   'platform': 'pc_web',
#   'marketplace': 'de',
#   'metric_name': 'views',
#   'metric_value': '900.0'},
#  {'timestamp': '2021-06-11 13:00:00',
#   'platform': 'pc_web',
#   'marketplace': 'it',
#   'metric_name': 'revenue',
#   'metric_value': '75.9'},
#  {'timestamp': '2021-06-11 14:00:00',
#   'platform': 'mobile_web',
#   'marketplace': 'de',
#   'metric_name': 'views',
#   'metric_value': '986.0'},
#  {'timestamp': '2021-06-11 14:00:00',
#   'platform': 'mobile_web',
#   'marketplace': 'es',
#   'metric_name': 'views',
#   'metric_value': '908.0'},
#  {'timestamp': '2021-06-11 14:00:00',
#   'platform': 'mobile_web',
#   'marketplace': 'jp',
#   'metric_name': 'views',
#   'metric_value': '726.0'},
#  {'timestamp': '2021-06-11 14:00:00',
#   'platform': 'mobile_web',
#   'marketplace': 'uk',
#   'metric_name': 'views',
#   'metric_value': '677.0'},
#  {'timestamp': '2021-06-11 14:00:00',
#   'platform': 'pc_web',
#   'marketplace': 'de',
#   'metric_name': 'views',
#   'metric_value': '1019.0'},
#  {'timestamp': '2021-06-11 15:00:00',
#   'platform': 'mobile_web',
#   'marketplace': 'de',
#   'metric_name': 'views',
#   'metric_value': '1084.0'},
#  {'timestamp': '2021-06-11 15:00:00',
#   'platform': 'mobile_web',
#   'marketplace': 'es',
#   'metric_name': 'views',
#   'metric_value': '959.0'},
#  {'timestamp': '2021-06-11 15:00:00',
#   'platform': 'mobile_web',
#   'marketplace': 'jp',
#   'metric_name': 'views',
#   'metric_value': '844.0'},
#  {'timestamp': '2021-06-11 15:00:00',
#   'platform': 'mobile_web',
#   'marketplace': 'uk',
#   'metric_name': 'views',
#   'metric_value': '804.0'},
#  {'timestamp': '2021-06-11 15:00:00',
#   'platform': 'pc_web',
#   'marketplace': 'de',
#   'metric_name': 'views',
#   'metric_value': '1097.0'},
#  {'timestamp': '2021-06-11 16:00:00',
#   'platform': 'mobile_web',
#   'marketplace': 'de',
#   'metric_name': 'views',
#   'metric_value': '1135.0'},
#  {'timestamp': '2021-06-11 16:00:00',
#   'platform': 'mobile_web',
#   'marketplace': 'es',
#   'metric_name': 'views',
#   'metric_value': '990.0'},
#  {'timestamp': '2021-06-11 16:00:00',
#   'platform': 'mobile_web',
#   'marketplace': 'jp',
#   'metric_name': 'views',
#   'metric_value': '943.0'},
#  {'timestamp': '2021-06-11 16:00:00',
#   'platform': 'mobile_web',
#   'marketplace': 'uk',
#   'metric_name': 'views',
#   'metric_value': '931.0'},
#  {'timestamp': '2021-06-11 16:00:00',
#   'platform': 'pc_web',
#   'marketplace': 'de',
#   'metric_name': 'views',
#   'metric_value': '1157.0'},
#  {'timestamp': '2021-06-11 17:00:00',
#   'platform': 'mobile_web',
#   'marketplace': 'de',
#   'metric_name': 'views',
#   'metric_value': '1165.0'},
#  {'timestamp': '2021-06-11 17:00:00',
#   'platform': 'mobile_web',
#   'marketplace': 'es',
#   'metric_name': 'views',
#   'metric_value': '983.0'},
#  {'timestamp': '2021-06-11 17:00:00',
#   'platform': 'mobile_web',
#   'marketplace': 'jp',
#   'metric_name': 'views',
#   'metric_value': '1024.0'},
#  {'timestamp': '2021-06-11 17:00:00',
#   'platform': 'mobile_web',
#   'marketplace': 'uk',
#   'metric_name': 'views',
#   'metric_value': '1042.0'},
#  {'timestamp': '2021-06-11 17:00:00',
#   'platform': 'pc_web',
#   'marketplace': 'de',
#   'metric_name': 'views',
#   'metric_value': '1188.0'},
#  {'timestamp': '2021-06-11 18:00:00',
#   'platform': 'mobile_web',
#   'marketplace': 'de',
#   'metric_name': 'views',
#   'metric_value': '1174.0'},
#  {'timestamp': '2021-06-11 18:00:00',
#   'platform': 'mobile_web',
#   'marketplace': 'es',
#   'metric_name': 'views',
#   'metric_value': '964.0'},
#  {'timestamp': '2021-06-11 18:00:00',
#   'platform': 'mobile_web',
#   'marketplace': 'jp',
#   'metric_name': 'views',
#   'metric_value': '1073.0'},
#  {'timestamp': '2021-06-11 18:00:00',
#   'platform': 'mobile_web',
#   'marketplace': 'uk',
#   'metric_name': 'views',
#   'metric_value': '1150.0'},
#  {'timestamp': '2021-06-11 18:00:00',
#   'platform': 'pc_web',
#   'marketplace': 'de',
#   'metric_name': 'views',
#   'metric_value': '1184.0'},
#  {'timestamp': '2021-06-11 19:00:00',
#   'platform': 'mobile_web',
#   'marketplace': 'de',
#   'metric_name': 'views',
#   'metric_value': '1135.0'},
#  {'timestamp': '2021-06-11 19:00:00',
#   'platform': 'mobile_web',
#   'marketplace': 'es',
#   'metric_name': 'views',
#   'metric_value': '931.0'},
#  {'timestamp': '2021-06-11 19:00:00',
#   'platform': 'mobile_web',
#   'marketplace': 'jp',
#   'metric_name': 'views',
#   'metric_value': '1100.0'},
#  {'timestamp': '2021-06-11 19:00:00',
#   'platform': 'mobile_web',
#   'marketplace': 'uk',
#   'metric_name': 'views',
#   'metric_value': '1218.0'},
#  {'timestamp': '2021-06-11 19:00:00',
#   'platform': 'pc_web',
#   'marketplace': 'de',
#   'metric_name': 'views',
#   'metric_value': '1151.0'},
#  {'timestamp': '2021-06-11 20:00:00',
#   'platform': 'mobile_web',
#   'marketplace': 'de',
#   'metric_name': 'views',
#   'metric_value': '1079.0'},
#  {'timestamp': '2021-06-11 20:00:00',
#   'platform': 'mobile_web',
#   'marketplace': 'es',
#   'metric_name': 'views',
#   'metric_value': '847.0'},
#  {'timestamp': '2021-06-11 20:00:00',
#   'platform': 'mobile_web',
#   'marketplace': 'jp',
#   'metric_name': 'views',
#   'metric_value': '1088.0'},
#  {'timestamp': '2021-06-11 20:00:00',
#   'platform': 'mobile_web',
#   'marketplace': 'uk',
#   'metric_name': 'views',
#   'metric_value': '1256.0'},
#  {'timestamp': '2021-06-11 20:00:00',
#   'platform': 'pc_web',
#   'marketplace': 'de',
#   'metric_name': 'views',
#   'metric_value': '1091.0'},
#  {'timestamp': '2021-06-11 21:00:00',
#   'platform': 'mobile_web',
#   'marketplace': 'de',
#   'metric_name': 'views',
#   'metric_value': '995.0'},
#  {'timestamp': '2021-06-11 21:00:00',
#   'platform': 'mobile_web',
#   'marketplace': 'es',
#   'metric_name': 'views',
#   'metric_value': '778.0'},
#  {'timestamp': '2021-06-11 21:00:00',
#   'platform': 'mobile_web',
#   'marketplace': 'jp',
#   'metric_name': 'views',
#   'metric_value': '1045.0'},
#  {'timestamp': '2021-06-11 21:00:00',
#   'platform': 'mobile_web',
#   'marketplace': 'uk',
#   'metric_name': 'views',
#   'metric_value': '1271.0'},
#  {'timestamp': '2021-06-11 21:00:00',
#   'platform': 'pc_web',
#   'marketplace': 'de',
#   'metric_name': 'views',
#   'metric_value': '999.0'},
#  {'timestamp': '2021-06-11 22:00:00',
#   'platform': 'mobile_web',
#   'marketplace': 'de',
#   'metric_name': 'views',
#   'metric_value': '883.0'},
#  {'timestamp': '2021-06-11 22:00:00',
#   'platform': 'mobile_web',
#   'marketplace': 'es',
#   'metric_name': 'views',
#   'metric_value': '664.0'},
#  {'timestamp': '2021-06-11 22:00:00',
#   'platform': 'mobile_web',
#   'marketplace': 'jp',
#   'metric_name': 'views',
#   'metric_value': '976.0'},
#  {'timestamp': '2021-06-11 22:00:00',
#   'platform': 'mobile_web',
#   'marketplace': 'uk',
#   'metric_name': 'views',
#   'metric_value': '1249.0'},
#  {'timestamp': '2021-06-11 22:00:00',
#   'platform': 'pc_web',
#   'marketplace': 'de',
#   'metric_name': 'views',
#   'metric_value': '905.0'},
#  {'timestamp': '2021-06-11 23:00:00',
#   'platform': 'mobile_web',
#   'marketplace': 'de',
#   'metric_name': 'views',
#   'metric_value': '763.0'},
#  {'timestamp': '2021-06-11 23:00:00',
#   'platform': 'mobile_web',
#   'marketplace': 'es',
#   'metric_name': 'views',
#   'metric_value': '571.0'},
#  {'timestamp': '2021-06-11 23:00:00',
#   'platform': 'mobile_web',
#   'marketplace': 'jp',
#   'metric_name': 'views',
#   'metric_value': '875.0'},
#  {'timestamp': '2021-06-11 23:00:00',
#   'platform': 'mobile_web',
#   'marketplace': 'uk',
#   'metric_name': 'views',
#   'metric_value': '1182.0'},
#  {'timestamp': '2021-06-11 23:00:00',
#   'platform': 'pc_web',
#   'marketplace': 'de',
#   'metric_name': 'views',
#   'metric_value': '775.0'}]

# %% [markdown]
# ---
# ### 6.3. Start the human review loop.

# %%
a2i_client = boto3.client('sagemaker-a2i-runtime')

humanLoopName = str(uuid.uuid4())

start_human_loop_response = a2i_client.start_human_loop(
            HumanLoopName=humanLoopName,
            FlowDefinitionArn=flowDefinitionArn,
            HumanLoopInput={
                "InputContent": json.dumps(ip_content)
            }
        )

print("\nStart human loop response: ")
#pprint.pprint(start_human_loop_response, width=2)

print("\nHuman Loop ARN: {}".format(start_human_loop_response['HumanLoopArn']))
# Out:
# Start human loop response:
#
# Human Loop ARN: arn:aws:sagemaker:us-west-2:095351214964:human-loop/b0e467fb-ca6b-4807-a0e9-8fb59e2baf13

# %% [markdown]
# ---
# By this time we should have already created a Workteam in the cosole and provided its ARN as input to an ealier cell. We use the Workteam name from the Workteam ARN, to find the URL of the portal for providing feedback on anomalies.

# %%
workteamName = workteam_ARN[workteam_ARN.rfind('/') + 1:]

describe_workteam_response = sagemaker_client.describe_workteam(WorkteamName=workteamName)

if not describe_workteam_response:
    print("You need to log into SageMaker console and create a Workteam")
    sys.exit()
 
#print("\nDescribe work team response: ")
#pprint.pprint(describe_workteam_response, width=2)

workteam_portal = 'https://' + describe_workteam_response['Workteam']['SubDomain']


print("\nLog into the work team portal link provided below, and review the anomalies.\n")

print ("=" * 60)
print("Portal URL\n{}".format(workteam_portal))
print ('=' * 60)

#print('https://' + sagemaker_client.describe_workteam(WorkteamName=workteamName)['Workteam']['SubDomain'])
# Out:
# Log into the work team portal link provided below, and review the anomalies.
#
# ============================================================
# Portal URL
# https://vwl3t7pqt6.labeling.us-west-2.sagemaker.aws
# ============================================================

# %% [markdown]
# ---
# ### 6.4. Complete the review
#
# The URL to the portal was printed out in the last step. Open the URL in a browser and log in with credentials of the human review worker. </br>
# You should have sent an invitation email to a worker for joining the workteam when creating the work team in the Amazon A2I console.

# %%
review_complete = 'N'

# %%
while review_complete == 'N':
    
    review_complete = input("\nPlease log into A2I Portal and complete the review.\nIs the review complete (Y/N)?")
    
    if review_complete == 'Y':
        break

# %%
completed_human_loops_s3_output = ""

try:
    describe_human_loop_response = a2i_client.describe_human_loop(HumanLoopName=humanLoopName)
    print("\nDescribe human loop response: ")
    pprint.pprint(describe_human_loop_response, width=2)
    
    completed_human_loops_s3_output = describe_human_loop_response["HumanLoopOutput"]["OutputS3Uri"]
    print("HumanLoop Status: {}".format(describe_human_loop_response["HumanLoopStatus"]))
except:
    print("Error getting human loop")


#print("\nHumanLoop Name: {}".format(humanLoopName))
#print("HumanLoop Status: {}".format(describe_human_loop_response["HumanLoopStatus"]))
print("\nOutput in S3 at: \n{}".format(describe_human_loop_response["HumanLoopOutput"]["OutputS3Uri"]))

# %%
pp = pprint.PrettyPrinter(indent=4)
json_output = ''

s3_bucket_name, s3_object_name = completed_human_loops_s3_output.replace("s3://", "").split("/", 1)

print("S3 bucket name: {}".format(s3_bucket_name))
print("S3 object name: {}".format(s3_object_name))

# Amazon S3 client 
s3_client = boto3.client('s3')

try:
    get_object_response = s3_client.get_object(Bucket=s3_bucket_name, Key=s3_object_name)
    content = get_object_response["Body"].read()
    json_output = json.loads(content)
    pp.pprint(json_output)
    print('\n')

except:
    print("Error getting S3 object: {}".format(completed_human_loops_s3_output))

#print("\nS3 get object response: ")
#pprint.pprint(get_object_response, width=2)


review_result = json_output['humanAnswers'][0]['answerContent']

#print(review_result)

# %% [markdown]
# ---
# ### 7.0. Update human review feedback in Amazon Lookout For Metrics
#
# This will help to improve the prediction accuracy.

# %%
if not L4M:
    L4M = boto3.client( "lookoutmetrics")

col_name_suffix = 1
anomaly_col_name = 'anomaly_found-' + str(col_name_suffix)

while anomaly_col_name in review_result:
    
    #tseriesid = review_result['tseriesid-' + str(col_name_suffix)]    
    
    print("\n{}".format(str(col_name_suffix)))
    
    is_anomaly = review_result[anomaly_col_name]['on']
    print("Is Anomaly: {}".format(is_anomaly))
        
    #print(df_anomalies_by_ts.loc[(df_anomalies_by_ts['timestamp'] == timestamp) & (df_anomalies_by_ts['marketplace'] ==marketplace) & (df_anomalies_by_ts['platform'] ==platform)])
    
    # get corresponding time series id and anomaly group id from dataframe df_anomalies_by_ts
    row_value = df_anomalies_by_ts.loc[(df_anomalies_by_ts['timestamp'] == timestamp) & (df_anomalies_by_ts['marketplace'] ==marketplace) & (df_anomalies_by_ts['platform'] ==platform)]
    #print("Row :{}".format(row_value))

    tseriesid = row_value['tseriesid'].tolist()[0]
    print("tseriesid: {}".format(tseriesid))
    
    anomaly_group_id = row_value['anomaly_group_id'].tolist()[0]
    print("Anomaly group id: {}".format(anomaly_group_id))
   
    #print('\nPut Feedback Response: {}'.format(put_feedback_response))
    
    col_name_suffix += 1
    anomaly_col_name = 'anomaly_found-' + str(col_name_suffix)

    put_feedback_response = L4M.put_feedback(
            AnomalyDetectorArn=ecom_anomaly_detector_arn,
            AnomalyGroupTimeSeriesFeedback={
                'AnomalyGroupId': anomaly_group_id,
                'TimeSeriesId': tseriesid,
                'IsAnomaly': is_anomaly}
    )

# %% [markdown]
# ---
# ### 8.0. Clean up resources
#
# You can start to cleanup the resources that were created. This will erase all the resources that have been created, so wait to run this until you are sure you wish to delete everything.
#
#
# **Note that since we created a continuous detector, it will continue to run once every hour until it is deleted.**

# %%
# Check if the detector exists
answer = input("Delete resources? (y/n)")

if answer in ["y", "Y", "yes", "YES"]:
    delete_resources = True
else:
    delete_resources = False
    
if delete_resources:
    L4M.delete_anomaly_detector( AnomalyDetectorArn = ecom_anomaly_detector_arn )
    while True:
        try:
            response = lookoutmetrics_client.describe_anomaly_detector( AnomalyDetectorArn = arn )
            if response["Status"] == "DELETING":
                print("status: DELETING")
                time.sleep(5)
                continue
            break
        except lookoutmetrics_client.exceptions.ResourceNotFoundException:
            break

    iam = boto3.client("iam")
    iam.detach_role_policy( PolicyArn = "arn:aws:iam::aws:policy/AmazonS3FullAccess", RoleName = role_name )
    iam.detach_role_policy( PolicyArn = "arn:aws:iam::aws:policy/AmazonSNSFullAccess", RoleName = role_name )
    iam.delete_role(RoleName=role_name)
    print("Deleted %s" % role_name)

# %%
# remove the resources

if delete_resources:
    
    # Check the status of human loop
    describe_human_loop_response = a2i_client.describe_human_loop(
        HumanLoopName=humanLoopName
    )

    print("\nDescribe human loop response: ")
    pprint.pprint(describe_human_loop_response, width=2)


    # 
    if describe_human_loop_response['HumanLoopStatus'] ==  "InProgress":
        stop_human_loop_response = a2i_client.stop_human_loop(
            HumanLoopName=humanLoopName
        )

        # Wait until human loop has stopped
        while True:
            describe_human_loop_response = a2i_client.describe_human_loop(
                HumanLoopName=humanLoopName
            )
            if describe_human_loop_response['HumanLoopStatus'] in ["Stopped", "Failed", "Completed"]:
                break
            time.sleep(5)
    
    
        # Delete human loop
        delete_human_loop_response = a2i_client.delete_human_loop(
            HumanLoopName=humanLoopName
        )
        print("\nDelete human loop response: ")
        pprint.pprint(delete_human_loop_response, width=2)
    
    # Delete work flow.
    delete_flow_definition_response = sagemaker_client.delete_flow_definition(
         FlowDefinitionName=l4m_flowDefinitionName
    )

    print("\nDelete flow definition response: ")
    pprint.pprint(delete_flow_definition_response, width=2)

    # Delete human task UI
    # Check if Amazon lookout for metrics UI exists
    try:
        delete_human_task_ui_response = sagemaker_client.delete_human_task_ui(
            HumanTaskUiName=l4m_taskUIName
        )
        print("\nDelete human task UI: ")
        pprint.pprint(delete_human_task_ui_response, width = 2)
    except:
        print("Human task UI {} not found".format(l4m_taskUIName))
